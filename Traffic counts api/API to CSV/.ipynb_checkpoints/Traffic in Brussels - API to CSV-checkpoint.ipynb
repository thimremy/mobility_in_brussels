# %% [markdown]
# # Introduction

# %% [markdown]
# On several locations in the Brussels Region, traffic is measured using magnetic loops or cameras. To access this data, we can use the API or the geowebservices. For the moment, only real-time data is available, historical data is coming.
#
# In this project, we're going to get the latest livestream data (the last 1-min interval available) for all detectors by traverse or by lane each time the code is run. We're going to extract, among other things, the number of vehicules passed between start and end time as well as the average speed of those counted vehicules.
#
# For more information on the API, please visit the [Brussels open datastore documentation](https://data-mobility.brussels/traffic/api/counts/).
#
# As a reminder, our ultimate goal is to display traffic data as well as other mobility data on a dynamic map of Brussels.
# You can check the latest version of our map on [our Tableau Public link](https://public.tableau.com/profile/remy2092#!/vizhome/TrafficinBrussels/TrafficinBrussels).

# %% [markdown]
# # Traffic counts api

# %% [markdown]
# Here are the 2 types of HTTP GET requests we can perform with the API:
#
# - `devices`: List with name and location of the traverses and their detectors by lane.
# - `live`: The latest livestream data for all detectors, by traverse or by lane. The data is updated every minute.

# %% [markdown]
# ## Devices request (traverses and their detectors)

# %% [markdown]
# We extract the data and create an json object to store it.

# %%
# We use the 'traverse_' prefix to describe the devices.

import requests
import json

traverse_devices_response = requests.get("http://data-mobility.brussels/traffic/api/counts/?request=devices")
traverse_devices_status_code = traverse_devices_response.status_code
traverse_devices_content = traverse_devices_response.content
decoded_traverse_devices_content = traverse_devices_content.decode('utf-8') # Decode using the utf-8 encoding
json_traverse_devices_content = json.loads(decoded_traverse_devices_content)
json_traverse_devices_content
# Out:
# {'requestDate': '2019/10/23 12:37:11',
#  'type': 'FeatureCollection',
#  'totalFeatures': 66,
#  'features': [{'type': 'Feature',
#    'id': 'traverse.16838',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.35695853200681, 50.8365913344471],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'LOU_TD1',
#     'descr_nl': 'Louizatunnel - inrit : Basiliek > Zuid + Kameren',
#     'descr_fr': 'Tunnel Louise - entrée : Basilique > Midi + Cambre',
#     'descr_en': 'Tunnel Louise - entrée : Basilique > Midi + Cambre',
#     'orientation': 50,
#     'number_of_lanes': 2,
#     'detectors': ['LOU_TD1_1', 'LOU_TD1_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16839',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.36852282769307, 50.8457551811458],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'ARL_103',
#     'descr_nl': 'Kunst-Wettunnel > Zuid',
#     'descr_fr': 'Tunnel Arts-Loi > Midi',
#     'descr_en': 'Tunnel Arts-Loi > Midi',
#     'orientation': 20,
#     'number_of_lanes': 2,
#     'detectors': ['ARL_103_1', 'ARL_103_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16858',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.34920696698087, 50.8579974792338],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'SB020_BBin',
#     'descr_nl': 'Boudewijnlaan : Helihavenlaan > IJzerplein',
#     'descr_fr': "Bd. Baudouin : Av. de l'Héliport > Pl. de l'Yser",
#     'descr_en': "Bd. Baudouin : Av. de l'Héliport > Pl. de l'Yser",
#     'orientation': 115,
#     'number_of_lanes': 2,
#     'detectors': ['SB020_BBin1', 'SB020_BBin2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16840',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.38682173223087, 50.8418347237431],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'LOI_103',
#     'descr_nl': 'Wettunnel : Jubelpark > Centrum',
#     'descr_fr': 'Tunnel Loi : Cinquantenaire > Centre',
#     'descr_en': 'Tunnel Loi : Cinquantenaire > Centre',
#     'orientation': 110,
#     'number_of_lanes': 2,
#     'detectors': ['LOI_103_1', 'LOI_103_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16835',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.35756294930224, 50.8930000247203],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'SB0236_BHout',
#     'descr_nl': 'Koninklijk Parklaan : Madridlaan > Vorstenhuislaan',
#     'descr_fr': 'Av. du Parc Royal : Av. de Madrid > Av. de la Dynastie',
#     'descr_en': 'Av. du Parc Royal : Av. de Madrid > Av. de la Dynastie',
#     'orientation': 320,
#     'number_of_lanes': 2,
#     'detectors': ['SB0236_BHout1', 'SB0236_BHout2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16849',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.39448722891204, 50.8402207235509],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'CIN_TD1',
#     'descr_nl': 'Jubelparktunnel > Centrum',
#     'descr_fr': 'Tunnel Cinquantenaire > Centre',
#     'descr_en': 'Tunnel Cinquantenaire > Centre',
#     'orientation': 110,
#     'number_of_lanes': 2,
#     'detectors': ['CIN_TD1_1', 'CIN_TD1_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16850',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.39448383899941, 50.8401254712678],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'CIN_TD2',
#     'descr_nl': 'Belliard-Jubelparktunnel > Tervueren',
#     'descr_fr': 'Tunnel Belliard-Cinquantenaire > Tervueren',
#     'descr_en': 'Tunnel Belliard-Cinquantenaire > Tervueren',
#     'orientation': 290,
#     'number_of_lanes': 2,
#     'detectors': ['CIN_TD2_1', 'CIN_TD2_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16851',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.39855753338851, 50.848036684476],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'RCE_TD1',
#     'descr_nl': 'Reyers-Centrumtunnel > Centrum',
#     'descr_fr': 'Tunnel Reyers-Centre > Centre',
#     'descr_en': 'Tunnel Reyers-Centre > Centre',
#     'orientation': 64,
#     'number_of_lanes': 1,
#     'detectors': ['RCE_TD1_1']}},
#   {'type': 'Feature',
#    'id': 'traverse.16866',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.38057760894757, 50.7990396839219],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'SUL62_BHin',
#     'descr_nl': 'Terhulpsesteenweg : Diesdellelaan > Lorrainedreef',
#     'descr_fr': "Ch. de la Hulpe : Av. du Vivier d'Oie > Dr. de Lorraine",
#     'descr_en': "Ch. de la Hulpe : Av. du Vivier d'Oie > Dr. de Lorraine",
#     'orientation': 280,
#     'number_of_lanes': 1,
#     'detectors': ['SUL62_BHin1']}},
#   {'type': 'Feature',
#    'id': 'traverse.16852',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.38083487018981, 50.8402353941657],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'BE_TD1',
#     'descr_nl': 'Belliardtunnel - inrit',
#     'descr_fr': 'Tunnel Belliard - entrée',
#     'descr_en': 'Tunnel Belliard - entrée',
#     'orientation': 260,
#     'number_of_lanes': 3,
#     'detectors': ['BE_TD1_1', 'BE_TD1_2', 'BE_TD1_3']}},
#   {'type': 'Feature',
#    'id': 'traverse.16865',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.36755767589685, 50.8427194155479],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'SB121_BBin',
#     'descr_nl': 'Belliardstraat : Kunstlaan > Handelsstraat',
#     'descr_fr': 'Rue Belliard : Av. des Arts > Rue du Commerce',
#     'descr_en': 'Rue Belliard : Av. des Arts > Rue du Commerce',
#     'orientation': 285,
#     'number_of_lanes': 5,
#     'detectors': ['SB121_BBin1',
#      'SB121_BBin2',
#      'SB121_BBin3',
#      'SB121_BBin4',
#      'SB121_BBin5']}},
#   {'type': 'Feature',
#    'id': 'traverse.16853',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.36847711930287, 50.8454212127438],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'ARL_203',
#     'descr_nl': 'Kunst-Wettunnel > Basiliek',
#     'descr_fr': 'Tunnel Arts-Loi > Basilique',
#     'descr_en': 'Tunnel Arts-Loi > Basilique',
#     'orientation': 200,
#     'number_of_lanes': 2,
#     'detectors': ['ARL_203_1', 'ARL_203_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16854',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.34435175156863, 50.8333292051346],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'HAL_292',
#     'descr_nl': 'Hallepoorttunnel > Basiliek',
#     'descr_fr': 'Tunnel Porte de Hal > Basilique',
#     'descr_en': 'Tunnel Porte de Hal > Basilique',
#     'orientation': 290,
#     'number_of_lanes': 2,
#     'detectors': ['HAL_292_1', 'HAL_292_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16844',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.36589069362988, 50.8406560215622],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'TRO_203',
#     'descr_nl': 'Troontunnel > Belliard',
#     'descr_fr': 'Tunnel Trône > Belliard',
#     'descr_en': 'Tunnel Trône > Belliard',
#     'orientation': 220,
#     'number_of_lanes': 2,
#     'detectors': ['TRO_203_1', 'TRO_203_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16836',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.37430823073347, 50.8413096175241],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'SB125_BBout',
#     'descr_nl': 'Belliardstraat : Aarlenstraat > Trierstraat',
#     'descr_fr': "Rue Belliard : Rue d'Arlon > rue de Trèves",
#     'descr_en': "Rue Belliard : Rue d'Arlon > rue de Trèves",
#     'orientation': 285,
#     'number_of_lanes': 4,
#     'detectors': ['SB125_BBout1',
#      'SB125_BBout2',
#      'SB125_BBout3',
#      'SB125_BBout4']}},
#   {'type': 'Feature',
#    'id': 'traverse.16859',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.36705817328361, 50.8529271483494],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'BOT_TD2',
#     'descr_nl': 'Kruidtuintunnel > Basiliek',
#     'descr_fr': 'Tunnel Botanique > Basilique',
#     'descr_en': 'Tunnel Botanique > Basilique',
#     'orientation': 120,
#     'number_of_lanes': 2,
#     'detectors': ['BOT_TD2_1', 'BOT_TD2_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16845',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.34504691225078, 50.8332713997418],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'HAL_191',
#     'descr_nl': 'Hallepoorttunnel > Zuid',
#     'descr_fr': 'Tunnel Porte de Hal > Midi',
#     'descr_en': 'Tunnel Porte de Hal > Midi',
#     'orientation': 110,
#     'number_of_lanes': 2,
#     'detectors': ['HAL_191_1', 'HAL_191_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16846',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.40763894749183, 50.8157452748348],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'DEL_103_12',
#     'descr_nl': 'Deltatunnel > Centre',
#     'descr_fr': 'Tunnel Delta > Centre',
#     'descr_en': 'Tunnel Delta > Centre',
#     'orientation': 135,
#     'number_of_lanes': 2,
#     'detectors': ['DEL_103_1', 'DEL_103_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16867',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.40739340672444, 50.8371268392137],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'MON_TD1',
#     'descr_nl': 'Montgomerytunnel > Kameren',
#     'descr_fr': 'Tunnel Montgomery > Cambre',
#     'descr_en': 'Tunnel Montgomery > Cambre',
#     'orientation': 15,
#     'number_of_lanes': 2,
#     'detectors': ['MON_TD1_1', 'MON_TD1_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16868',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.35470097195641, 50.835614034075],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'LOU_110',
#     'descr_nl': 'Louizatunnel - lus : Basiliek > Kameren',
#     'descr_fr': 'Tunnel Louise - boucle : Basilique > Cambre',
#     'descr_en': 'Tunnel Louise - boucle : Basilique > Cambre',
#     'orientation': 105,
#     'number_of_lanes': 1,
#     'detectors': ['LOU_110_6']}},
#   {'type': 'Feature',
#    'id': 'traverse.16869',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.35551041573263, 50.8357236560642],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'STE_TD3',
#     'descr_nl': 'Stefaniatunnel - oprit : Kameren > Basiliek',
#     'descr_fr': 'Tunnel Stéphanie - bretelle : Cambre > Basilique',
#     'descr_en': 'Tunnel Stéphanie - bretelle : Cambre > Basilique',
#     'orientation': 190,
#     'number_of_lanes': 1,
#     'detectors': ['STE_TD3_1']}},
#   {'type': 'Feature',
#    'id': 'traverse.16860',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.38279259633245, 50.7979060948513],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'SUL62_BGin',
#     'descr_nl': 'Lorrainedreef : Korporaaldreef > Terhulpsesteenweg',
#     'descr_fr': 'Dr. de Lorraine : Dr. du Caporal > Ch. de la Hulpe',
#     'descr_en': 'Dr. de Lorraine : Dr. du Caporal > Ch. de la Hulpe',
#     'orientation': 170,
#     'number_of_lanes': 2,
#     'detectors': ['SUL62_BGin1', 'SUL62_BGin2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16847',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.36897150728288, 50.8491539713291],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'MAD_103',
#     'descr_nl': 'Madoutunnel > Zuid',
#     'descr_fr': 'Tunnel Madou > Midi',
#     'descr_en': 'Tunnel Madou > Midi',
#     'orientation': 350,
#     'number_of_lanes': 2,
#     'detectors': ['MAD_103_1', 'MAD_103_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16848',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.36796757498138, 50.8233719130158],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'VLE_103',
#     'descr_nl': 'Vleurgattunnel > Centrum',
#     'descr_fr': 'Tunnel Vleurgat > Centre',
#     'descr_en': 'Tunnel Vleurgat > Centre',
#     'orientation': 150,
#     'number_of_lanes': 2,
#     'detectors': ['VLE_103_1', 'VLE_103_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16875',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.35529733515802, 50.8560960838814],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'ROG_TD1',
#     'descr_nl': 'Rogier-Kruidtuintunnel > Zuid',
#     'descr_fr': 'Tunnel Rogier-Botanique > Midi',
#     'descr_en': 'Tunnel Rogier-Botanique > Midi',
#     'orientation': 295,
#     'number_of_lanes': 2,
#     'detectors': ['ROG_TD1_1', 'ROG_TD1_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16818',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.36169819780213, 50.8384799439303],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'PNA_203',
#     'descr_nl': 'Naamsepoorttunnel > Basiliek',
#     'descr_fr': 'Tunnel Porte de Namur > Basilique',
#     'descr_en': 'Tunnel Porte de Namur > Basilique',
#     'orientation': 235,
#     'number_of_lanes': 2,
#     'detectors': ['PNA_203_1', 'PNA_203_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16819',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.40760212115242, 50.8156243058095],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'DEL_103_6',
#     'descr_nl': 'Deltatunnel > Parking',
#     'descr_fr': 'Tunnel Delta > Parking',
#     'descr_en': 'Tunnel Delta > Parking',
#     'orientation': 110,
#     'number_of_lanes': 1,
#     'detectors': ['DEL_103_6']}},
#   {'type': 'Feature',
#    'id': 'traverse.16870',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.38058685119678, 50.7990691599242],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'SUL62_BDout',
#     'descr_nl': 'Terhulpsesteenweg : Lorrainedreef > Diesdellelaan',
#     'descr_fr': "Ch. de la Hulpe : Dr. de Lorraine > Av. du Vivier d'Oie",
#     'descr_en': "Ch. de la Hulpe : Dr. de Lorraine > Av. du Vivier d'Oie",
#     'orientation': 100,
#     'number_of_lanes': 1,
#     'detectors': ['SUL62_BDout1']}},
#   {'type': 'Feature',
#    'id': 'traverse.16876',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.3552931128139, 50.8357944967423],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'LOU_TD2',
#     'descr_nl': 'Louizatunnel - inrit : Zuid > Basiliek',
#     'descr_fr': 'Tunnel Louise - entrée : Midi > Basilique',
#     'descr_en': 'Tunnel Louise - entrée : Midi > Basilique',
#     'orientation': 230,
#     'number_of_lanes': 2,
#     'detectors': ['LOU_TD2_1', 'LOU_TD2_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16820',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.37525612793937, 50.8790703836989],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'VP_103',
#     'descr_nl': 'Van Praettunnel > Centrum',
#     'descr_fr': 'Tunnel Van Praet > Centre',
#     'descr_en': 'Tunnel Van Praet > Centre',
#     'orientation': 5,
#     'number_of_lanes': 2,
#     'detectors': ['VP_103_1', 'VP_103_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16821',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.35544182807463, 50.8353942207238],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'STE_TD2',
#     'descr_nl': 'Stefaniatunnel - uitrit : Centrum + Basiliek > Kameren',
#     'descr_fr': 'Tunnel Stéphanie - sortie : Centre + Basilique > Cambre',
#     'descr_en': 'Tunnel Stéphanie - sortie : Centre + Basilique > Cambre',
#     'orientation': 325,
#     'number_of_lanes': 2,
#     'detectors': ['STE_TD2_1', 'STE_TD2_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16822',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.40454037395511, 50.8314671373189],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'BOI_203',
#     'descr_nl': 'Boileautunnel > Meiser',
#     'descr_fr': 'Tunnel Boileau > Meiser',
#     'descr_en': 'Tunnel Boileau > Meiser',
#     'orientation': 200,
#     'number_of_lanes': 2,
#     'detectors': ['BOI_203_1', 'BOI_203_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16837',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.4061742687768, 50.8424655931645],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'GH_103',
#     'descr_nl': 'Georges Henritunnel > Ter Kameren',
#     'descr_fr': 'Tunnel Georges Henri > La Cambre',
#     'descr_en': 'Tunnel Georges Henri > La Cambre',
#     'orientation': 340,
#     'number_of_lanes': 3,
#     'detectors': ['GH_103_1', 'GH_103_2', 'GH_103_3']}},
#   {'type': 'Feature',
#    'id': 'traverse.16823',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.35553982742218, 50.8560957594291],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'ROG_TD2',
#     'descr_nl': 'Rogiertunnel > Basiliek',
#     'descr_fr': 'Tunnel Rogier > Basilique',
#     'descr_en': 'Tunnel Rogier > Basilique',
#     'orientation': 115,
#     'number_of_lanes': 2,
#     'detectors': ['ROG_TD2_1', 'ROG_TD2_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16841',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.30990478561637, 50.8691421209151],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'SGN02_BBout',
#     'descr_nl': 'Keizer Karellaan : F. Beeckmansstraat > de Villegaslaan',
#     'descr_fr': 'Av. Charles-Quint : Rue F. Beeckmans > Av. de Villegas',
#     'descr_en': 'Av. Charles-Quint : Rue F. Beeckmans > Av. de Villegas',
#     'orientation': 115,
#     'number_of_lanes': 2,
#     'detectors': ['SGN02_BBout1', 'SGN02_BBout2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16842',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.40797458487389, 50.8373973283749],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'TER_TD1',
#     'descr_nl': 'Tervurentunnel > Centrum',
#     'descr_fr': 'Tunnel Tervueren > Centre',
#     'descr_en': 'Tunnel Tervueren > Centre',
#     'orientation': 110,
#     'number_of_lanes': 2,
#     'detectors': ['TER_TD1_1', 'TER_TD1_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16824',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.38602388862269, 50.8433192595553],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'BEL_TD4',
#     'descr_nl': 'Belliard-Cortenberghtunnel vóór inrit Blijde Inkomst > E40',
#     'descr_fr': 'Tunnel Belliard-Cortenbergh avant entrée Joyeuse Entrée > E40',
#     'descr_en': 'Tunnel Belliard-Cortenbergh avant entrée Joyeuse Entrée > E40',
#     'orientation': 230,
#     'number_of_lanes': 2,
#     'detectors': ['BEL_TD4_1', 'BEL_TD4_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16825',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.40240769836913, 50.8498633167017],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'RME_TD1',
#     'descr_nl': 'Reyers-Meisertunnel > Meiser',
#     'descr_fr': 'Tunnel Reyers-Meiser > Meiser',
#     'descr_en': 'Tunnel Reyers-Meiser > Meiser',
#     'orientation': 120,
#     'number_of_lanes': 1,
#     'detectors': ['RME_TD1_1']}},
#   {'type': 'Feature',
#    'id': 'traverse.16861',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.36676532148926, 50.8420224998488],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'SB1201_BAout',
#     'descr_nl': 'Kunstlaan : Montoyerstraat > Belliardstraat',
#     'descr_fr': 'Av. des Arts : Rue Montoyer > Rue Belliard',
#     'descr_en': 'Av. des Arts : Rue Montoyer > Rue Belliard',
#     'orientation': 195,
#     'number_of_lanes': 4,
#     'detectors': ['SB1201_BAout1',
#      'SB1201_BAout2',
#      'SB1201_BAout3',
#      'SB1201_BAout4']}},
#   {'type': 'Feature',
#    'id': 'traverse.16826',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.35533670092783, 50.8356012609392],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'STE_TD1',
#     'descr_nl': 'Stefaniatunnel - uitrit : Kameren > Centrum',
#     'descr_fr': 'Tunnel Stéphanie - sortie : Cambre > Centre',
#     'descr_en': 'Tunnel Stéphanie - sortie : Cambre > Centre',
#     'orientation': 140,
#     'number_of_lanes': 1,
#     'detectors': ['STE_TD1_1']}},
#   {'type': 'Feature',
#    'id': 'traverse.16855',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.36338369892443, 50.8932787104298],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'SB0246_BAout',
#     'descr_nl': 'Vuurkruisenlaan : Heembeekstraat > De Wandstraat',
#     'descr_fr': 'Av. des Croix du Feu : rue de Heembeek > rue de Wand',
#     'descr_en': 'Av. des Croix du Feu : rue de Heembeek > rue de Wand',
#     'orientation': 125,
#     'number_of_lanes': 2,
#     'detectors': ['SB0246_BAout3', 'SB0246_BAout4']}},
#   {'type': 'Feature',
#    'id': 'traverse.16827',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.36618462645944, 50.8411585614729],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'TRO_TD2',
#     'descr_nl': 'Troontunnel > Basilique',
#     'descr_fr': 'Tunnel Trône > Basilique',
#     'descr_en': 'Tunnel Trône > Basilique',
#     'orientation': 200,
#     'number_of_lanes': 2,
#     'detectors': ['TRO_TD2_1', 'TRO_TD2_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16843',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.40646945858465, 50.8422366718252],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'GH_203',
#     'descr_nl': 'Georges Henritunnel > Meiser',
#     'descr_fr': 'Tunnel Georges Henri > Meiser',
#     'descr_en': 'Tunnel Georges Henri > Meiser',
#     'orientation': 160,
#     'number_of_lanes': 3,
#     'detectors': ['GH_203_1', 'GH_203_2', 'GH_203_3']}},
#   {'type': 'Feature',
#    'id': 'traverse.16856',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.3105789088027, 50.8688324426319],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'SGN02_BAout',
#     'descr_nl': 'Keizer Karellaan : F. Beeckmansstraat > Boerderijstraat',
#     'descr_fr': 'Av. Charles-Quint : Rue F. Beeckmans > Rue de la Métairie',
#     'descr_en': 'Av. Charles-Quint : Rue F. Beeckmans > Rue de la Métairie',
#     'orientation': 295,
#     'number_of_lanes': 2,
#     'detectors': ['SGN02_BAout1', 'SGN02_BAout2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16863',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.34876977877793, 50.8582030897834],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'SB020_BCin',
#     'descr_nl': 'Willebroekkaai : Ruimingskaai > IJzerplein',
#     'descr_fr': "Quai de Willebroeck : Quai de la Voirie > Pl. de l'Yser",
#     'descr_en': "Quai de Willebroeck : Quai de la Voirie > Pl. de l'Yser",
#     'orientation': 25,
#     'number_of_lanes': 3,
#     'detectors': ['SB020_BCin1', 'SB020_BCin2', 'SB020_BCin3']}},
#   {'type': 'Feature',
#    'id': 'traverse.16828',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.3623772388971, 50.8388649715647],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'PNA_103',
#     'descr_nl': 'Naamsepoorttunnel > Zuid',
#     'descr_fr': 'Tunnel Porte de Namur > Midi',
#     'descr_en': 'Tunnel Porte de Namur > Midi',
#     'orientation': 55,
#     'number_of_lanes': 2,
#     'detectors': ['PNA_103_1', 'PNA_103_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16864',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.38398848375424, 50.7985971582363],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'SUL62_BHout',
#     'descr_nl': "Terhulpsesteenweg : Lorrainedreef > 's-Herenhuislaan",
#     'descr_fr': "Ch. de la Hulpe : Dr. de Lorraine > Av. S'Heeren Huys",
#     'descr_en': "Ch. de la Hulpe : Dr. de Lorraine > Av. S'Heeren Huys",
#     'orientation': 280,
#     'number_of_lanes': 2,
#     'detectors': ['SUL62_BHout1', 'SUL62_BHout2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16862',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.38247616107358, 50.7990014935703],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'SUL62_BGout',
#     'descr_nl': 'Lorrainedreef : Terhulpsesteenweg > Bosvoordselaan',
#     'descr_fr': 'Dr. de Lorraine : Ch. de la Hulpe > Av. de Boitsfort',
#     'descr_en': 'Dr. de Lorraine : Ch. de la Hulpe > Av. de Boitsfort',
#     'orientation': 210,
#     'number_of_lanes': 1,
#     'detectors': ['SUL62_BGout1']}},
#   {'type': 'Feature',
#    'id': 'traverse.16829',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.36916800191254, 50.8488531910046],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'MAD_203',
#     'descr_nl': 'Madoutunnel > Basiliek',
#     'descr_fr': 'Tunnel Madou > Basilique',
#     'descr_en': 'Tunnel Madou > Basilique',
#     'orientation': 170,
#     'number_of_lanes': 2,
#     'detectors': ['MAD_203_1', 'MAD_203_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16830',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.3674756097824, 50.8237391810756],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'VLE_203',
#     'descr_nl': 'Vleurgattunnel > Ter Kameren',
#     'descr_fr': 'Tunnel Vleurgat > La Cambre',
#     'descr_en': 'Tunnel Vleurgat > La Cambre',
#     'orientation': 330,
#     'number_of_lanes': 2,
#     'detectors': ['VLE_103_1', 'VLE_103_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16831',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.38650625946081, 50.8417380768795],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'BET_TD3',
#     'descr_nl': 'Belliard-Jubelparktunnel > Tervueren',
#     'descr_fr': 'Tunnel Belliard-Cinquantenaire > Tervueren',
#     'descr_en': 'Tunnel Belliard-Cinquantenaire > Tervueren',
#     'orientation': 290,
#     'number_of_lanes': 2,
#     'detectors': ['BET_TD3_1', 'BET_TD3_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16832',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.37533832168132, 50.8786382689061],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'VP_203',
#     'descr_nl': 'Van Praettunnel > A12',
#     'descr_fr': 'Tunnel Van Praet > A12',
#     'descr_en': 'Tunnel Van Praet > A12',
#     'orientation': 185,
#     'number_of_lanes': 2,
#     'detectors': ['VP_203_1', 'VP_203_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16871',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.38273308951594, 50.7978984925948],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'SUL62_BA1out',
#     'descr_nl': 'Lorrainedreef : Terhulpsesteenweg > Korporaaldreef',
#     'descr_fr': 'Dr. de Lorraine : Ch. de la Hulpe > Dr. du Caporal',
#     'descr_en': 'Dr. de Lorraine : Ch. de la Hulpe > Dr. du Caporal',
#     'orientation': 350,
#     'number_of_lanes': 1,
#     'detectors': ['SUL62_BA1out1']}},
#   {'type': 'Feature',
#    'id': 'traverse.16877',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.38400074128935, 50.7986361284092],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'SUL62_BDin',
#     'descr_nl': "Terhulpsesteenweg : 's-Herenhuislaan > Lorrainedreef",
#     'descr_fr': "Ch. de la Hulpe : Av. S'Heeren Huys > Dr. de Lorraine",
#     'descr_en': "Ch. de la Hulpe : Av. S'Heeren Huys > Dr. de Lorraine",
#     'orientation': 100,
#     'number_of_lanes': 1,
#     'detectors': ['SUL62_BDin1']}},
#   {'type': 'Feature',
#    'id': 'traverse.16872',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.3632826010712, 50.8926726489919],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'SB0246_BXout',
#     'descr_nl': 'Van Praetlaan : Araucarialaan > Vilvoordsesteenweg',
#     'descr_fr': "Av. Van Praet : Av. de l'Araucaria > Ch. de Vilvorde",
#     'descr_en': "Av. Van Praet : Av. de l'Araucaria > Ch. de Vilvorde",
#     'orientation': 295,
#     'number_of_lanes': 2,
#     'detectors': ['SB0246_BXout1', 'SB0246_BXout2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16873',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.34919110900498, 50.8582377341188],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'SB020_BDout',
#     'descr_nl': 'Willebroekkaai : IJzerplein > Simon Bolivarlaan',
#     'descr_fr': "Quai de Willebroeck : Pl. de l'Yser > Bd S. Bolivar",
#     'descr_en': "Quai de Willebroeck : Pl. de l'Yser > Bd S. Bolivar",
#     'orientation': 200,
#     'number_of_lanes': 2,
#     'detectors': ['SB020_BDout1', 'SB020_BDout2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16833',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.36312754900289, 50.8279565134595],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'BAI_TD2',
#     'descr_nl': 'Baillitunnel > Ter Kameren',
#     'descr_fr': 'Tunnel Bailli > La Cambre',
#     'descr_en': 'Tunnel Bailli > La Cambre',
#     'orientation': 330,
#     'number_of_lanes': 2,
#     'detectors': ['BAI_TD2_1', 'BAI_TD2_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16834',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.36302375091686, 50.8281804402839],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'BAI_TD1',
#     'descr_nl': 'Baillitunnel > Centrum',
#     'descr_fr': 'Tunnel Bailli > Centre',
#     'descr_en': 'Tunnel Bailli > Centre',
#     'orientation': 150,
#     'number_of_lanes': 2,
#     'detectors': ['BAI_TD1_1', 'BAI_TD1_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16878',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.38594029684627, 50.8412923720853],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'LOI_109',
#     'descr_nl': 'Wettunnel : inrit Blijde Inkomst > Centrum',
#     'descr_fr': 'Tunnel Loi : entrée Joyeuse Entrée > Centre',
#     'descr_en': 'Tunnel Loi : entrée Joyeuse Entrée > Centre',
#     'orientation': 200,
#     'number_of_lanes': 1,
#     'detectors': ['LOI_109_6']}},
#   {'type': 'Feature',
#    'id': 'traverse.16879',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.34917883601026, 50.8577737668987],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'SB020_BAout',
#     'descr_nl': 'Antwerpselaan : IJzerplein > Antwerpselaan',
#     'descr_fr': "Bd. d'Anvers : Pl. de l'Yser > Bd. d'Anvers",
#     'descr_en': "Bd. d'Anvers : Pl. de l'Yser > Bd. d'Anvers",
#     'orientation': 290,
#     'number_of_lanes': 2,
#     'detectors': ['SB020_BAout1', 'SB020_BAout2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16874',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.40752081535691, 50.8371066241582],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'MON_TD2',
#     'descr_nl': 'Montgomerytunnel > Meiser',
#     'descr_fr': 'Tunnel Montgomery > Meiser',
#     'descr_en': 'Tunnel Montgomery > Meiser',
#     'orientation': 195,
#     'number_of_lanes': 2,
#     'detectors': ['MON_TD2_1', 'MON_TD2_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16880',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.35760384671979, 50.8931166449733],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'SB0236_BCout',
#     'descr_nl': 'Koninklijk Parklaan : Madridlaan > A12',
#     'descr_fr': 'Av. du Parc Royal : Av. de Madrid > A12',
#     'descr_en': 'Av. du Parc Royal : Av. de Madrid > A12',
#     'orientation': 140,
#     'number_of_lanes': 2,
#     'detectors': ['SB0236_BCout1', 'SB0236_BCout2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16881',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.36627279945376, 50.8415215046334],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'TRO_TD1',
#     'descr_nl': 'Troontunnel > Zuid',
#     'descr_fr': 'Tunnel Trône > Midi',
#     'descr_en': 'Tunnel Trône > Midi',
#     'orientation': 20,
#     'number_of_lanes': 2,
#     'detectors': ['TRO_TD1_1', 'TRO_TD1_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16882',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.38459966479754, 50.8421984666756],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'BET_TD2_12',
#     'descr_nl': 'Belliardtunnel - bifurcatie > Jubelpark',
#     'descr_fr': 'Tunnel Belliard - bifurcation > Cinquantenaire',
#     'descr_en': 'Tunnel Belliard - bifurcation > Cinquantenaire',
#     'orientation': 290,
#     'number_of_lanes': 2,
#     'detectors': ['BET_TD2_1', 'BET_TD2_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16883',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.40717157399957, 50.8374887718277],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'TER_TD2',
#     'descr_nl': 'Tervurentunnel > Tervuren',
#     'descr_fr': 'Tunnel Tervueren > Tervueren',
#     'descr_en': 'Tunnel Tervueren > Tervueren',
#     'orientation': 290,
#     'number_of_lanes': 2,
#     'detectors': ['TER_TD2_1', 'TER_TD2_2']}},
#   {'type': 'Feature',
#    'id': 'traverse.16884',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.3949361577435, 50.8471522117605],
#     'geometry_name': 'geom'},
#    'properties': {'traverse_name': 'BEL_TD5',
#     'descr_nl': 'Belliard-Cortenberghtunnel > E40',
#     'descr_fr': 'Tunnel Belliard-Cortenbergh > E40',
#     'descr_en': 'Tunnel Belliard-Cortenbergh > E40',
#     'orientation': 240,
#     'number_of_lanes': 2,
#     'detectors': ['BEL_TD5_1', 'BEL_TD5_2']}}]}

# %% [markdown]
# We are interested by the `features` key where all the attributes of each traverse is stored.
# We are first going to create an empty DataFrame to allow us to store all this information.

# %%
import pandas as pd

traverse_devices_df = pd.DataFrame(columns = ["traverse_request_date", "traverse_id", "traverse_name", "traverse_descr_nl", 
                                              "traverse_descr_fr", "traverse_descr_en", "traverse_longitude", 
                                              "traverse_latitude", "traverse_orientation", "traverse_number_of_lanes", 
                                              "detector_1", "detector_2", "detector_3", "detector_4", "detector_5"])

# %% [markdown]
# We are extracting the content of the json object to fill our DataFrame.

# %%
traverse_request_date = json_traverse_devices_content["requestDate"]

i = 0

for item in json_traverse_devices_content['features']:
    traverse_id = item["id"]
    traverse_longitude = item["geometry"]["coordinates"][0]
    traverse_latitude = item["geometry"]["coordinates"][1]
    traverse_name = item["properties"]["traverse_name"]
    traverse_descr_nl = item["properties"]["descr_nl"]
    traverse_descr_fr = item["properties"]["descr_fr"]
    traverse_descr_en = item["properties"]["descr_en"]
    traverse_orientation = item["properties"]["orientation"]
    traverse_number_of_lanes = item["properties"]["number_of_lanes"]
    
    detector_dict = dict.fromkeys(["detector_1", "detector_2", "detector_3", "detector_4", "detector_5"])
    detector_list = ["detector_1", "detector_2", "detector_3", "detector_4", "detector_5"]
    det_count = 0
    for detector in item["properties"]["detectors"]:
        detector_dict[detector_list[det_count]] = detector
        det_count += 1
    traverse_devices_df.loc[i] = [traverse_request_date, traverse_id, traverse_name, traverse_descr_nl, traverse_descr_fr, 
                                  traverse_descr_en, traverse_longitude, traverse_latitude, traverse_orientation, 
                                  traverse_number_of_lanes, detector_dict["detector_1"], detector_dict["detector_2"], 
                                  detector_dict["detector_3"], detector_dict["detector_4"], detector_dict["detector_5"]]  
    i += 1

# %% [markdown]
# In order for the `traverse_longitude`and `traverse_latitude` columns to be considered as geographical data by Tableau, we need to convert them as string.

# %%
coordinates = ["traverse_longitude", "traverse_latitude"]

for coord in coordinates:
    traverse_devices_df[coord] = traverse_devices_df[coord].astype(str).str.replace(".", ",")

traverse_devices_df[["traverse_longitude", "traverse_latitude"]]
# Out:
#    traverse_longitude traverse_latitude
# 0    4,35695853200681  50,8365913344471
# 1    4,36852282769307  50,8457551811458
# 2    4,34920696698087  50,8579974792338
# 3    4,38682173223087  50,8418347237431
# 4    4,35756294930224  50,8930000247203
# 5    4,39448722891204  50,8402207235509
# 6    4,39448383899941  50,8401254712678
# 7    4,39855753338851   50,848036684476
# 8    4,38057760894757  50,7990396839219
# 9    4,38083487018981  50,8402353941657
# 10   4,36755767589685  50,8427194155479
# 11   4,36847711930287  50,8454212127438
# 12   4,34435175156863  50,8333292051346
# 13   4,36589069362988  50,8406560215622
# 14   4,37430823073347  50,8413096175241
# 15   4,36705817328361  50,8529271483494
# 16   4,34504691225078  50,8332713997418
# 17   4,40763894749183  50,8157452748348
# 18   4,40739340672444  50,8371268392137
# 19   4,35470097195641   50,835614034075
# 20   4,35551041573263  50,8357236560642
# 21   4,38279259633245  50,7979060948513
# 22   4,36897150728288  50,8491539713291
# 23   4,36796757498138  50,8233719130158
# 24   4,35529733515802  50,8560960838814
# 25   4,36169819780213  50,8384799439303
# 26   4,40760212115242  50,8156243058095
# 27   4,38058685119678  50,7990691599242
# 28    4,3552931128139  50,8357944967423
# 29   4,37525612793937  50,8790703836989
# ..                ...               ...
# 36   4,38602388862269  50,8433192595553
# 37   4,40240769836913  50,8498633167017
# 38   4,36676532148926  50,8420224998488
# 39   4,35533670092783  50,8356012609392
# 40   4,36338369892443  50,8932787104298
# 41   4,36618462645944  50,8411585614729
# 42   4,40646945858465  50,8422366718252
# 43    4,3105789088027  50,8688324426319
# 44   4,34876977877793  50,8582030897834
# 45    4,3623772388971  50,8388649715647
# 46   4,38398848375424  50,7985971582363
# 47   4,38247616107358  50,7990014935703
# 48   4,36916800191254  50,8488531910046
# 49    4,3674756097824  50,8237391810756
# 50   4,38650625946081  50,8417380768795
# 51   4,37533832168132  50,8786382689061
# 52   4,38273308951594  50,7978984925948
# 53   4,38400074128935  50,7986361284092
# 54    4,3632826010712  50,8926726489919
# 55   4,34919110900498  50,8582377341188
# 56   4,36312754900289  50,8279565134595
# 57   4,36302375091686  50,8281804402839
# 58   4,38594029684627  50,8412923720853
# 59   4,34917883601026  50,8577737668987
# 60   4,40752081535691  50,8371066241582
# 61   4,35760384671979  50,8931166449733
# 62   4,36627279945376  50,8415215046334
# 63   4,38459966479754  50,8421984666756
# 64   4,40717157399957  50,8374887718277
# 65    4,3949361577435  50,8471522117605
#
# [66 rows x 2 columns]

# %% [markdown]
# We drop `traverse_descr_en` as it contains the same information as `traverse_descr_fr`.

# %%
traverse_devices_df.drop("traverse_descr_en", axis=1, inplace=True)

# %%
traverse_devices_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66 entries, 0 to 65
# Data columns (total 14 columns):
# traverse_request_date       66 non-null object
# traverse_id                 66 non-null object
# traverse_name               66 non-null object
# traverse_descr_nl           66 non-null object
# traverse_descr_fr           66 non-null object
# traverse_longitude          66 non-null object
# traverse_latitude           66 non-null object
# traverse_orientation        66 non-null object
# traverse_number_of_lanes    66 non-null object
# detector_1                  66 non-null object
# detector_2                  54 non-null object
# detector_3                  7 non-null object
# detector_4                  3 non-null object
# detector_5                  1 non-null object
# dtypes: object(14)
# memory usage: 7.7+ KB

# %% [markdown]
# We only overwrite the existing file if detectors are added.

# %%
# TO DO: uncomment the below line and define your path on where to save your file.
# my_path = ""

import os

if not os.path.isfile(my_path):
    traverse_devices_df.to_csv(my_path, sep=";")
else:
    old_traverse_devices_df = pd.read_csv(my_path, delimiter=";")
    old_traverse_devices_df.shape[0]
    if traverse_devices_df.shape[0] != old_traverse_devices_df.shape[0]:
        traverse_devices_df.to_csv(my_path, sep=";")

# %% [markdown]
# We create the list of traverse names as we'll need it to extract live data.

# %%
list_of_traverse_name = []
for item in json_traverse_devices_content["features"]:
    traverse_name = item["properties"]["traverse_name"]
    list_of_traverse_name.append(traverse_name)

list_of_traverse_name
# Out:
# ['LOU_TD1',
#  'ARL_103',
#  'SB020_BBin',
#  'LOI_103',
#  'SB0236_BHout',
#  'CIN_TD1',
#  'CIN_TD2',
#  'RCE_TD1',
#  'SUL62_BHin',
#  'BE_TD1',
#  'SB121_BBin',
#  'ARL_203',
#  'HAL_292',
#  'TRO_203',
#  'SB125_BBout',
#  'BOT_TD2',
#  'HAL_191',
#  'DEL_103_12',
#  'MON_TD1',
#  'LOU_110',
#  'STE_TD3',
#  'SUL62_BGin',
#  'MAD_103',
#  'VLE_103',
#  'ROG_TD1',
#  'PNA_203',
#  'DEL_103_6',
#  'SUL62_BDout',
#  'LOU_TD2',
#  'VP_103',
#  'STE_TD2',
#  'BOI_203',
#  'GH_103',
#  'ROG_TD2',
#  'SGN02_BBout',
#  'TER_TD1',
#  'BEL_TD4',
#  'RME_TD1',
#  'SB1201_BAout',
#  'STE_TD1',
#  'SB0246_BAout',
#  'TRO_TD2',
#  'GH_203',
#  'SGN02_BAout',
#  'SB020_BCin',
#  'PNA_103',
#  'SUL62_BHout',
#  'SUL62_BGout',
#  'MAD_203',
#  'VLE_203',
#  'BET_TD3',
#  'VP_203',
#  'SUL62_BA1out',
#  'SUL62_BDin',
#  'SB0246_BXout',
#  'SB020_BDout',
#  'BAI_TD2',
#  'BAI_TD1',
#  'LOI_109',
#  'SB020_BAout',
#  'MON_TD2',
#  'SB0236_BCout',
#  'TRO_TD1',
#  'BET_TD2_12',
#  'TER_TD2',
#  'BEL_TD5']

# %% [markdown]
# ## Live request

# %% [markdown]
# Here are the parameters of the live request:
#
# - featureID: Optional parameter for :w live requests. The value should be a traverse name or lane detector.
# - interval: Optional parameter for live requests. The parameters makes a filter for the measurement time space. Possible values are '1', '5', '15', '60' and 'all'. The value defines the time space in minutes. The default value 'all', gives you all data.
# - includeLanes: Optional parameter for live requests. If the parameter is set 'true', the response gives also the data by lane. The default value is 'false'.
# - singleValue: Optional parameter for live requests. If the parameter is set 'true', the response gives only the last timestamp value. The default value is 'false'.
#
# Below we extract the real-time data off all the traverse and create an json object to store it.
#
# We will only focus on the last minute (`interval`: 1) and we'll take the last timestamp (`singleValue`: true).

# %%
parameters = {'request': 'live', 'interval': '1', 'singleValue': 'true'}
traverse_live_response = requests.get("http://data-mobility.brussels/traffic/api/counts/", params=parameters)
traverse_live_status_code = traverse_live_response.status_code
traverse_live_content = traverse_live_response.content
decoded_traverse_live_content = traverse_live_content.decode('utf-8') # Decode using the utf-8 encoding
json_traverse_live_content = json.loads(decoded_traverse_live_content)
json_traverse_live_content
# Out:
# {'requestDate': '2019/10/23 12:37:17',
#  'data': {'ARL_103': {'results': {'1m': {'count': 41,
#      'speed': 24.0,
#      'occupancy': 50.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'ARL_203': {'results': {'1m': {'count': 19,
#      'speed': 16.5,
#      'occupancy': 36.5,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'BAI_TD1': {'results': {'1m': {'count': 18,
#      'speed': 46.0,
#      'occupancy': 12.5,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'BAI_TD2': {'results': {'1m': {'count': 28,
#      'speed': 48.0,
#      'occupancy': 20.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'BEL_TD4': {'results': {'1m': {'count': 16,
#      'speed': 76.0,
#      'occupancy': 6.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'BEL_TD5': {'results': {'1m': {'count': 37,
#      'speed': 45.5,
#      'occupancy': 22.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'BE_TD1': {'results': {'1m': {'count': 64,
#      'speed': 60.3333,
#      'occupancy': 25.3333,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'BET_TD2_12': {'results': {'1m': {'count': 13,
#      'speed': 47.0,
#      'occupancy': 7.5,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'BET_TD3': {'results': {'1m': {'count': 9,
#      'speed': 63.0,
#      'occupancy': 5.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'BOI_203': {'results': {'1m': {'count': 40,
#      'speed': 37.0,
#      'occupancy': 29.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'BOT_TD2': {'results': {'1m': {'count': 31,
#      'speed': 18.5,
#      'occupancy': 47.5,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'CIN_TD1': {'results': {'1m': {'count': 45,
#      'speed': 54.0,
#      'occupancy': 28.5,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'CIN_TD2': {'results': {'1m': {'count': 22,
#      'speed': 65.5,
#      'occupancy': 14.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'DEL_103_12': {'results': {'1m': {'count': 32,
#      'speed': 53.5,
#      'occupancy': 17.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'DEL_103_6': {'results': {'1m': {'count': 0,
#      'speed': 0.0,
#      'occupancy': 0.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'GH_103': {'results': {'1m': {'count': 41,
#      'speed': 57.3333,
#      'occupancy': 16.3333,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'GH_203': {'results': {'1m': {'count': 37,
#      'speed': 73.6667,
#      'occupancy': 13.6667,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'HAL_191': {'results': {'1m': {'count': 21,
#      'speed': 42.0,
#      'occupancy': 15.5,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'HAL_292': {'results': {'1m': {'count': 13,
#      'speed': 28.0,
#      'occupancy': 6.5,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'LOI_103': {'results': {'1m': {'count': 33,
#      'speed': 58.0,
#      'occupancy': 12.5,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'LOI_109': {'results': {'1m': {'count': 2,
#      'speed': 51.0,
#      'occupancy': 1.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'LOU_110': {'results': {'1m': {'count': 14,
#      'speed': 36.0,
#      'occupancy': 18.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'LOU_TD1': {'results': {'1m': {'count': 36,
#      'speed': 50.5,
#      'occupancy': 26.5,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'LOU_TD2': {'results': {'1m': {'count': 31,
#      'speed': 57.0,
#      'occupancy': 12.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'MAD_103': {'results': {'1m': {'count': 53,
#      'speed': 34.0,
#      'occupancy': 29.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'MAD_203': {'results': {'1m': {'count': 19,
#      'speed': 18.5,
#      'occupancy': 42.5,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'MON_TD1': {'results': {'1m': {'count': 21,
#      'speed': 62.5,
#      'occupancy': 11.5,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'MON_TD2': {'results': {'1m': {'count': 17,
#      'speed': 64.0,
#      'occupancy': 9.5,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'PNA_103': {'results': {'1m': {'count': 54,
#      'speed': 51.5,
#      'occupancy': 38.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'PNA_203': {'results': {'1m': {'count': 38,
#      'speed': 25.5,
#      'occupancy': 39.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'RCE_TD1': {'results': {'1m': {'count': 14,
#      'speed': 44.0,
#      'occupancy': 23.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'RME_TD1': {'results': {'1m': {'count': 12,
#      'speed': 45.0,
#      'occupancy': 16.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'ROG_TD1': {'results': {'1m': {'count': 34,
#      'speed': 56.5,
#      'occupancy': 13.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'ROG_TD2': {'results': {'1m': {'count': 27,
#      'speed': 60.0,
#      'occupancy': 15.5,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'SB020_BAout': {'results': {'1m': {'count': 19,
#      'speed': 31.5,
#      'occupancy': 11.0,
#      'start_time': '2019/10/23 12:32',
#      'end_time': '2019/10/23 12:33'}}},
#   'SB020_BBin': {'results': {'1m': {'count': 14,
#      'speed': 30.5,
#      'occupancy': 9.0,
#      'start_time': '2019/10/23 12:32',
#      'end_time': '2019/10/23 12:33'}}},
#   'SB020_BCin': {'results': {'1m': {'count': 9,
#      'speed': 14.3333,
#      'occupancy': 2.33333,
#      'start_time': '2019/10/23 12:32',
#      'end_time': '2019/10/23 12:33'}}},
#   'SB020_BDout': {'results': {'1m': {'count': 18,
#      'speed': 34.5,
#      'occupancy': 8.5,
#      'start_time': '2019/10/23 12:32',
#      'end_time': '2019/10/23 12:33'}}},
#   'SB0236_BCout': {'results': {'1m': {'count': 18,
#      'speed': 36.5,
#      'occupancy': 8.0,
#      'start_time': '2019/10/23 12:32',
#      'end_time': '2019/10/23 12:33'}}},
#   'SB1201_BAout': {'results': {'1m': {'count': 29,
#      'speed': 16.25,
#      'occupancy': 18.0,
#      'start_time': '2019/10/23 12:32',
#      'end_time': '2019/10/23 12:33'}}},
#   'SGN02_BBout': {'results': {'1m': {'count': 20,
#      'speed': 22.5,
#      'occupancy': 14.0,
#      'start_time': '2019/10/23 12:32',
#      'end_time': '2019/10/23 12:33'}}},
#   'STE_TD1': {'results': {'1m': {'count': 5,
#      'speed': 35.0,
#      'occupancy': 7.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'STE_TD2': {'results': {'1m': {'count': 27,
#      'speed': 54.0,
#      'occupancy': 18.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'STE_TD3': {'results': {'1m': {'count': 16,
#      'speed': 27.0,
#      'occupancy': 21.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'SUL62_BGout': {'results': {'1m': {'count': 8,
#      'speed': 32.0,
#      'occupancy': 3.0,
#      'start_time': '2019/10/23 12:32',
#      'end_time': '2019/10/23 12:33'}}},
#   'TER_TD1': {'results': {'1m': {'count': 3,
#      'speed': 12.5,
#      'occupancy': 2.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'TER_TD2': {'results': {'1m': {'count': 15,
#      'speed': 17.0,
#      'occupancy': 13.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'TRO_203': {'results': {'1m': {'count': 8,
#      'speed': 11.5,
#      'occupancy': 16.5,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'TRO_TD1': {'results': {'1m': {'count': 44,
#      'speed': 54.5,
#      'occupancy': 27.5,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'TRO_TD2': {'results': {'1m': {'count': 24,
#      'speed': 15.0,
#      'occupancy': 49.5,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'VLE_103': {'results': {'1m': {'count': 32,
#      'speed': 62.0,
#      'occupancy': 22.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'VLE_203': {'results': {'1m': {'count': 32,
#      'speed': 62.0,
#      'occupancy': 22.0,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'VP_103': {'results': {'1m': {'count': 6,
#      'speed': 55.5,
#      'occupancy': 5.5,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'VP_203': {'results': {'1m': {'count': 19,
#      'speed': 56.5,
#      'occupancy': 13.5,
#      'start_time': '2019/10/23 12:35',
#      'end_time': '2019/10/23 12:36'}}},
#   'SUL62_BGin': {'results': {'1m': {'count': None,
#      'speed': None,
#      'occupancy': None,
#      'start_time': '-',
#      'end_time': '-'}}},
#   'SB121_BBin': {'results': {'1m': {'count': None,
#      'speed': None,
#      'occupancy': None,
#      'start_time': '-',
#      'end_time': '-'}}},
#   'SB0246_BXout': {'results': {'1m': {'count': None,
#      'speed': None,
#      'occupancy': None,
#      'start_time': '-',
#      'end_time': '-'}}},
#   'SB125_BBin': {'results': {'1m': {'count': None,
#      'speed': None,
#      'occupancy': None,
#      'start_time': '-',
#      'end_time': '-'}}},
#   'SB0236_BHout': {'results': {'1m': {'count': None,
#      'speed': None,
#      'occupancy': None,
#      'start_time': '-',
#      'end_time': '-'}}},
#   'SB125_BBout': {'results': {'1m': {'count': None,
#      'speed': None,
#      'occupancy': None,
#      'start_time': '-',
#      'end_time': '-'}}},
#   'SUL62_BDout': {'results': {'1m': {'count': None,
#      'speed': None,
#      'occupancy': None,
#      'start_time': '-',
#      'end_time': '-'}}},
#   'SGN02_BAout': {'results': {'1m': {'count': None,
#      'speed': None,
#      'occupancy': None,
#      'start_time': '-',
#      'end_time': '-'}}},
#   'SUL62_BHout': {'results': {'1m': {'count': None,
#      'speed': None,
#      'occupancy': None,
#      'start_time': '-',
#      'end_time': '-'}}},
#   'SUL62_BDin': {'results': {'1m': {'count': None,
#      'speed': None,
#      'occupancy': None,
#      'start_time': '-',
#      'end_time': '-'}}},
#   'SUL62_BA1out': {'results': {'1m': {'count': None,
#      'speed': None,
#      'occupancy': None,
#      'start_time': '-',
#      'end_time': '-'}}},
#   'SB0246_BAout': {'results': {'1m': {'count': None,
#      'speed': None,
#      'occupancy': None,
#      'start_time': '-',
#      'end_time': '-'}}},
#   'SUL62_BHin': {'results': {'1m': {'count': None,
#      'speed': None,
#      'occupancy': None,
#      'start_time': '-',
#      'end_time': '-'}}}}}

# %% [markdown]
# We are interested by the `data` key where all the real-time data of each traverse is stored.
# We are first going to create an empty DataFrame to allow us to store all this information.

# %%
traverse_live_df = pd.DataFrame(columns = ['traverse_live_request_date', 'traverse_name', 'traverse_interval', 'traverse_count', 
                                           'traverse_speed', 'traverse_occupancy','traverse_start_time', 'traverse_end_time'])

# %% [markdown]
# We are extracting the content of the json object to fill our DataFrame.

# %%
traverse_live_request_date = json_traverse_live_content["requestDate"]
traverse_interval = '1m'
i = 0

for col in list_of_traverse_name:
    traverse_name = col
    traverse_count = json_traverse_live_content["data"][col]["results"][traverse_interval]["count"]
    traverse_speed = json_traverse_live_content["data"][col]["results"][traverse_interval]["speed"]
    traverse_occupancy = json_traverse_live_content["data"][col]["results"][traverse_interval]["occupancy"]
    traverse_start_time = json_traverse_live_content["data"][col]["results"][traverse_interval]["start_time"]
    traverse_end_time = json_traverse_live_content["data"][col]["results"][traverse_interval]["end_time"]
    
    traverse_live_df.loc[i] = [traverse_live_request_date, traverse_name, traverse_interval, traverse_count, traverse_speed, 
                               traverse_occupancy, traverse_start_time, traverse_end_time]
    i += 1

# %% [markdown]
# We start by dropping rows with null values as it won't be used in our visualizations.

# %%
traverse_live_df.dropna(inplace = True)

# %% [markdown]
# In order for the `traverse_speed`and `traverse_occupancy` columns to be considered as float numbers by Tableau, we need to convert them as string and replace "." by ",".

# %%
measures = ["traverse_speed", "traverse_occupancy"]

for measure in measures:
    traverse_live_df.loc[traverse_live_df[measure] < 0, measure] = 0
    traverse_live_df[measure] = traverse_live_df[measure].astype(str).str.replace(".", ",")

traverse_live_df[["traverse_speed", "traverse_occupancy"]]
# Out:
#    traverse_speed traverse_occupancy
# 0            50,5               26,5
# 1            24,0               50,0
# 2            30,5                9,0
# 3            58,0               12,5
# 5            54,0               28,5
# 6            65,5               14,0
# 7            44,0               23,0
# 9         60,3333            25,3333
# 11           16,5               36,5
# 12           28,0                6,5
# 13           11,5               16,5
# 15           18,5               47,5
# 16           42,0               15,5
# 17           53,5               17,0
# 18           62,5               11,5
# 19           36,0               18,0
# 20           27,0               21,0
# 22           34,0               29,0
# 23           62,0               22,0
# 24           56,5               13,0
# 25           25,5               39,0
# 26            0,0                0,0
# 28           57,0               12,0
# 29           55,5                5,5
# 30           54,0               18,0
# 31           37,0               29,0
# 32        57,3333            16,3333
# 33           60,0               15,5
# 34           22,5               14,0
# 35           12,5                2,0
# 36           76,0                6,0
# 37           45,0               16,0
# 38          16,25               18,0
# 39           35,0                7,0
# 41           15,0               49,5
# 42        73,6667            13,6667
# 44        14,3333            2,33333
# 45           51,5               38,0
# 47           32,0                3,0
# 48           18,5               42,5
# 49           62,0               22,0
# 50           63,0                5,0
# 51           56,5               13,5
# 55           34,5                8,5
# 56           48,0               20,0
# 57           46,0               12,5
# 58           51,0                1,0
# 59           31,5               11,0
# 60           64,0                9,5
# 61           36,5                8,0
# 62           54,5               27,5
# 63           47,0                7,5
# 64           17,0               13,0
# 65           45,5               22,0

# %% [markdown]
# In order for the `traverse_request_date`, `traverse_start_time` and `traverse_end_time` columns to be considered as dates by Tableau, we need apply some formatting.

# %%
traverse_live_df["traverse_live_request_date"] = pd.to_datetime(traverse_live_df["traverse_live_request_date"], 
                                                                format='%Y/%m/%d %H:%M')
traverse_live_df["traverse_start_time"] = pd.to_datetime(traverse_live_df["traverse_start_time"], format='%Y/%m/%d %H:%M', 
                                                         errors = 'coerce')
traverse_live_df["traverse_end_time"] = pd.to_datetime(traverse_live_df["traverse_end_time"], format='%Y/%m/%d %H:%M', 
                                                       errors = 'coerce')
traverse_live_df["traverse_end_date"] = traverse_live_df["traverse_end_time"].dt.date
traverse_live_df["traverse_end_hour"] = traverse_live_df["traverse_end_time"].dt.time

# %%
traverse_live_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 0 to 65
# Data columns (total 10 columns):
# traverse_live_request_date    54 non-null datetime64[ns]
# traverse_name                 54 non-null object
# traverse_interval             54 non-null object
# traverse_count                54 non-null object
# traverse_speed                54 non-null object
# traverse_occupancy            54 non-null object
# traverse_start_time           54 non-null datetime64[ns]
# traverse_end_time             54 non-null datetime64[ns]
# traverse_end_date             54 non-null object
# traverse_end_hour             54 non-null object
# dtypes: datetime64[ns](3), object(7)
# memory usage: 4.6+ KB

# %% [markdown]
# We append new rows to the existing .csv file.

# %%
# TO DO: uncomment the below line and define your path on where to save your file.
# my_path = ""

import datetime

if not os.path.isfile(my_path):
    traverse_live_df.to_csv(my_path, sep=";")
else:
    old_traverse_live_df = pd.read_csv(my_path, delimiter=";")
    
    for index, row in traverse_live_df.iterrows():
        traverse_live_last_update = row["traverse_end_time"]
        traverse_name = row["traverse_name"]
        old_traverse_live_last_update = old_traverse_live_df.loc[old_traverse_live_df["traverse_name"] == traverse_name, 
                                                                 "traverse_end_time"].max()
        old_traverse_live_last_update = datetime.datetime.strptime(old_traverse_live_last_update, '%Y-%m-%d %H:%M:%S')

        if traverse_live_last_update <= old_traverse_live_last_update:
            traverse_live_df.drop(index, axis=0, inplace=True)
    
    traverse_live_df.to_csv(my_path, sep=";", mode='a', header=False)
