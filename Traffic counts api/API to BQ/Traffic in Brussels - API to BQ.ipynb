# %% [markdown]
# # Introduction

# %% [markdown]
# On several locations in the Brussels Region, traffic is measured using magnetic loops or cameras. To access this data, we can use the API or the geowebservices. For the moment, only real-time data is available, historical data is coming.
#
# In this project, we're going to get the latest livestream data (the last 1-min interval available) for all detectors by traverse or by lane each time the code is run. We're going to extract, among other things, the number of vehicules passed between start and end time as well as the average speed of those counted vehicules.
#
# For more information on the API, please visit the [Brussels open datastore documentation](https://data-mobility.brussels/traffic/api/counts/).
#
# As a reminder, our ultimate goal is to display traffic data as well as other mobility data on a dynamic map of Brussels.
# You can check the latest version of our map on [our Tableau Online link](https://eu-west-1a.online.tableau.com/t/thimremy/views/TrafficinBrussels/TrafficinBrussels?iframeSizedToWindow=true&:embed=y&:showAppBanner=false&:display_count=no&:showVizHome=no&:origin=viz_share_link) (a new link with hourly refreshed map will be published soon).

# %% [markdown]
# # Traffic counts api

# %% [markdown]
# Here are the 2 types of HTTP GET requests we can perform with the API:
#
# - `devices`: List with name and location of the traverses and their detectors by lane.
# - `live`: The latest livestream data for all detectors, by traverse or by lane. The data is updated every minute.

# %% [markdown]
# ## Devices request (traverses and their detectors)

# %% [markdown]
# We extract the data and create an json object to store it.

# %%
# We use the 'traverse_' prefix to describe the devices.

import requests
import json

traverse_devices_response = requests.get("http://data-mobility.brussels/traffic/api/counts/?request=devices")
traverse_devices_status_code = traverse_devices_response.status_code
traverse_devices_content = traverse_devices_response.content
decoded_traverse_devices_content = traverse_devices_content.decode('utf-8') # Decode using the utf-8 encoding
json_traverse_devices_content = json.loads(decoded_traverse_devices_content)
json_traverse_devices_content
# Out:
# {'features': [{'geometry': {'coordinates': [4.35695853200681,
#      50.8365913344471],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16838',
#    'properties': {'descr_en': 'Tunnel Louise - entrée : Basilique > Midi + Cambre',
#     'descr_fr': 'Tunnel Louise - entrée : Basilique > Midi + Cambre',
#     'descr_nl': 'Louizatunnel - inrit : Basiliek > Zuid + Kameren',
#     'detectors': ['LOU_TD1_1', 'LOU_TD1_2'],
#     'number_of_lanes': 2,
#     'orientation': 50,
#     'traverse_name': 'LOU_TD1'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.36852282769307, 50.8457551811458],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16839',
#    'properties': {'descr_en': 'Tunnel Arts-Loi > Midi',
#     'descr_fr': 'Tunnel Arts-Loi > Midi',
#     'descr_nl': 'Kunst-Wettunnel > Zuid',
#     'detectors': ['ARL_103_1', 'ARL_103_2'],
#     'number_of_lanes': 2,
#     'orientation': 20,
#     'traverse_name': 'ARL_103'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.34920696698087, 50.8579974792338],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16858',
#    'properties': {'descr_en': "Bd. Baudouin : Av. de l'Héliport > Pl. de l'Yser",
#     'descr_fr': "Bd. Baudouin : Av. de l'Héliport > Pl. de l'Yser",
#     'descr_nl': 'Boudewijnlaan : Helihavenlaan > IJzerplein',
#     'detectors': ['SB020_BBin1', 'SB020_BBin2'],
#     'number_of_lanes': 2,
#     'orientation': 115,
#     'traverse_name': 'SB020_BBin'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.38682173223087, 50.8418347237431],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16840',
#    'properties': {'descr_en': 'Tunnel Loi : Cinquantenaire > Centre',
#     'descr_fr': 'Tunnel Loi : Cinquantenaire > Centre',
#     'descr_nl': 'Wettunnel : Jubelpark > Centrum',
#     'detectors': ['LOI_103_1', 'LOI_103_2'],
#     'number_of_lanes': 2,
#     'orientation': 110,
#     'traverse_name': 'LOI_103'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.35756294930224, 50.8930000247203],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16835',
#    'properties': {'descr_en': 'Av. du Parc Royal : Av. de Madrid > Av. de la Dynastie',
#     'descr_fr': 'Av. du Parc Royal : Av. de Madrid > Av. de la Dynastie',
#     'descr_nl': 'Koninklijk Parklaan : Madridlaan > Vorstenhuislaan',
#     'detectors': ['SB0236_BHout1', 'SB0236_BHout2'],
#     'number_of_lanes': 2,
#     'orientation': 320,
#     'traverse_name': 'SB0236_BHout'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.39448722891204, 50.8402207235509],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16849',
#    'properties': {'descr_en': 'Tunnel Cinquantenaire > Centre',
#     'descr_fr': 'Tunnel Cinquantenaire > Centre',
#     'descr_nl': 'Jubelparktunnel > Centrum',
#     'detectors': ['CIN_TD1_1', 'CIN_TD1_2'],
#     'number_of_lanes': 2,
#     'orientation': 110,
#     'traverse_name': 'CIN_TD1'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.39448383899941, 50.8401254712678],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16850',
#    'properties': {'descr_en': 'Tunnel Belliard-Cinquantenaire > Tervueren',
#     'descr_fr': 'Tunnel Belliard-Cinquantenaire > Tervueren',
#     'descr_nl': 'Belliard-Jubelparktunnel > Tervueren',
#     'detectors': ['CIN_TD2_1', 'CIN_TD2_2'],
#     'number_of_lanes': 2,
#     'orientation': 290,
#     'traverse_name': 'CIN_TD2'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.39855753338851, 50.848036684476],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16851',
#    'properties': {'descr_en': 'Tunnel Reyers-Centre > Centre',
#     'descr_fr': 'Tunnel Reyers-Centre > Centre',
#     'descr_nl': 'Reyers-Centrumtunnel > Centrum',
#     'detectors': ['RCE_TD1_1'],
#     'number_of_lanes': 1,
#     'orientation': 64,
#     'traverse_name': 'RCE_TD1'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.38057760894757, 50.7990396839219],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16866',
#    'properties': {'descr_en': "Ch. de la Hulpe : Av. du Vivier d'Oie > Dr. de Lorraine",
#     'descr_fr': "Ch. de la Hulpe : Av. du Vivier d'Oie > Dr. de Lorraine",
#     'descr_nl': 'Terhulpsesteenweg : Diesdellelaan > Lorrainedreef',
#     'detectors': ['SUL62_BHin1'],
#     'number_of_lanes': 1,
#     'orientation': 280,
#     'traverse_name': 'SUL62_BHin'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.38083487018981, 50.8402353941657],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16852',
#    'properties': {'descr_en': 'Tunnel Belliard - entrée',
#     'descr_fr': 'Tunnel Belliard - entrée',
#     'descr_nl': 'Belliardtunnel - inrit',
#     'detectors': ['BE_TD1_1', 'BE_TD1_2', 'BE_TD1_3'],
#     'number_of_lanes': 3,
#     'orientation': 260,
#     'traverse_name': 'BE_TD1'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.36755767589685, 50.8427194155479],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16865',
#    'properties': {'descr_en': 'Rue Belliard : Av. des Arts > Rue du Commerce',
#     'descr_fr': 'Rue Belliard : Av. des Arts > Rue du Commerce',
#     'descr_nl': 'Belliardstraat : Kunstlaan > Handelsstraat',
#     'detectors': ['SB121_BBin1',
#      'SB121_BBin2',
#      'SB121_BBin3',
#      'SB121_BBin4',
#      'SB121_BBin5'],
#     'number_of_lanes': 5,
#     'orientation': 285,
#     'traverse_name': 'SB121_BBin'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.36847711930287, 50.8454212127438],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16853',
#    'properties': {'descr_en': 'Tunnel Arts-Loi > Basilique',
#     'descr_fr': 'Tunnel Arts-Loi > Basilique',
#     'descr_nl': 'Kunst-Wettunnel > Basiliek',
#     'detectors': ['ARL_203_1', 'ARL_203_2'],
#     'number_of_lanes': 2,
#     'orientation': 200,
#     'traverse_name': 'ARL_203'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.34435175156863, 50.8333292051346],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16854',
#    'properties': {'descr_en': 'Tunnel Porte de Hal > Basilique',
#     'descr_fr': 'Tunnel Porte de Hal > Basilique',
#     'descr_nl': 'Hallepoorttunnel > Basiliek',
#     'detectors': ['HAL_292_1', 'HAL_292_2'],
#     'number_of_lanes': 2,
#     'orientation': 290,
#     'traverse_name': 'HAL_292'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.36589069362988, 50.8406560215622],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16844',
#    'properties': {'descr_en': 'Tunnel Trône > Belliard',
#     'descr_fr': 'Tunnel Trône > Belliard',
#     'descr_nl': 'Troontunnel > Belliard',
#     'detectors': ['TRO_203_1', 'TRO_203_2'],
#     'number_of_lanes': 2,
#     'orientation': 220,
#     'traverse_name': 'TRO_203'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.37430823073347, 50.8413096175241],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16836',
#    'properties': {'descr_en': "Rue Belliard : Rue d'Arlon > rue de Trèves",
#     'descr_fr': "Rue Belliard : Rue d'Arlon > rue de Trèves",
#     'descr_nl': 'Belliardstraat : Aarlenstraat > Trierstraat',
#     'detectors': ['SB125_BBout1',
#      'SB125_BBout2',
#      'SB125_BBout3',
#      'SB125_BBout4'],
#     'number_of_lanes': 4,
#     'orientation': 285,
#     'traverse_name': 'SB125_BBout'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.36705817328361, 50.8529271483494],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16859',
#    'properties': {'descr_en': 'Tunnel Botanique > Basilique',
#     'descr_fr': 'Tunnel Botanique > Basilique',
#     'descr_nl': 'Kruidtuintunnel > Basiliek',
#     'detectors': ['BOT_TD2_1', 'BOT_TD2_2'],
#     'number_of_lanes': 2,
#     'orientation': 120,
#     'traverse_name': 'BOT_TD2'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.34504691225078, 50.8332713997418],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16845',
#    'properties': {'descr_en': 'Tunnel Porte de Hal > Midi',
#     'descr_fr': 'Tunnel Porte de Hal > Midi',
#     'descr_nl': 'Hallepoorttunnel > Zuid',
#     'detectors': ['HAL_191_1', 'HAL_191_2'],
#     'number_of_lanes': 2,
#     'orientation': 110,
#     'traverse_name': 'HAL_191'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.40763894749183, 50.8157452748348],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16846',
#    'properties': {'descr_en': 'Tunnel Delta > Centre',
#     'descr_fr': 'Tunnel Delta > Centre',
#     'descr_nl': 'Deltatunnel > Centre',
#     'detectors': ['DEL_103_1', 'DEL_103_2'],
#     'number_of_lanes': 2,
#     'orientation': 135,
#     'traverse_name': 'DEL_103_12'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.40739340672444, 50.8371268392137],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16867',
#    'properties': {'descr_en': 'Tunnel Montgomery > Cambre',
#     'descr_fr': 'Tunnel Montgomery > Cambre',
#     'descr_nl': 'Montgomerytunnel > Kameren',
#     'detectors': ['MON_TD1_1', 'MON_TD1_2'],
#     'number_of_lanes': 2,
#     'orientation': 15,
#     'traverse_name': 'MON_TD1'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.35470097195641, 50.835614034075],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16868',
#    'properties': {'descr_en': 'Tunnel Louise - boucle : Basilique > Cambre',
#     'descr_fr': 'Tunnel Louise - boucle : Basilique > Cambre',
#     'descr_nl': 'Louizatunnel - lus : Basiliek > Kameren',
#     'detectors': ['LOU_110_6'],
#     'number_of_lanes': 1,
#     'orientation': 105,
#     'traverse_name': 'LOU_110'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.35551041573263, 50.8357236560642],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16869',
#    'properties': {'descr_en': 'Tunnel Stéphanie - bretelle : Cambre > Basilique',
#     'descr_fr': 'Tunnel Stéphanie - bretelle : Cambre > Basilique',
#     'descr_nl': 'Stefaniatunnel - oprit : Kameren > Basiliek',
#     'detectors': ['STE_TD3_1'],
#     'number_of_lanes': 1,
#     'orientation': 190,
#     'traverse_name': 'STE_TD3'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.38279259633245, 50.7979060948513],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16860',
#    'properties': {'descr_en': 'Dr. de Lorraine : Dr. du Caporal > Ch. de la Hulpe',
#     'descr_fr': 'Dr. de Lorraine : Dr. du Caporal > Ch. de la Hulpe',
#     'descr_nl': 'Lorrainedreef : Korporaaldreef > Terhulpsesteenweg',
#     'detectors': ['SUL62_BGin1', 'SUL62_BGin2'],
#     'number_of_lanes': 2,
#     'orientation': 170,
#     'traverse_name': 'SUL62_BGin'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.36897150728288, 50.8491539713291],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16847',
#    'properties': {'descr_en': 'Tunnel Madou > Midi',
#     'descr_fr': 'Tunnel Madou > Midi',
#     'descr_nl': 'Madoutunnel > Zuid',
#     'detectors': ['MAD_103_1', 'MAD_103_2'],
#     'number_of_lanes': 2,
#     'orientation': 350,
#     'traverse_name': 'MAD_103'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.36796757498138, 50.8233719130158],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16848',
#    'properties': {'descr_en': 'Tunnel Vleurgat > Centre',
#     'descr_fr': 'Tunnel Vleurgat > Centre',
#     'descr_nl': 'Vleurgattunnel > Centrum',
#     'detectors': ['VLE_103_1', 'VLE_103_2'],
#     'number_of_lanes': 2,
#     'orientation': 150,
#     'traverse_name': 'VLE_103'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.35529733515802, 50.8560960838814],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16875',
#    'properties': {'descr_en': 'Tunnel Rogier-Botanique > Midi',
#     'descr_fr': 'Tunnel Rogier-Botanique > Midi',
#     'descr_nl': 'Rogier-Kruidtuintunnel > Zuid',
#     'detectors': ['ROG_TD1_1', 'ROG_TD1_2'],
#     'number_of_lanes': 2,
#     'orientation': 295,
#     'traverse_name': 'ROG_TD1'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.36169819780213, 50.8384799439303],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16818',
#    'properties': {'descr_en': 'Tunnel Porte de Namur > Basilique',
#     'descr_fr': 'Tunnel Porte de Namur > Basilique',
#     'descr_nl': 'Naamsepoorttunnel > Basiliek',
#     'detectors': ['PNA_203_1', 'PNA_203_2'],
#     'number_of_lanes': 2,
#     'orientation': 235,
#     'traverse_name': 'PNA_203'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.40760212115242, 50.8156243058095],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16819',
#    'properties': {'descr_en': 'Tunnel Delta > Parking',
#     'descr_fr': 'Tunnel Delta > Parking',
#     'descr_nl': 'Deltatunnel > Parking',
#     'detectors': ['DEL_103_6'],
#     'number_of_lanes': 1,
#     'orientation': 110,
#     'traverse_name': 'DEL_103_6'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.38058685119678, 50.7990691599242],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16870',
#    'properties': {'descr_en': "Ch. de la Hulpe : Dr. de Lorraine > Av. du Vivier d'Oie",
#     'descr_fr': "Ch. de la Hulpe : Dr. de Lorraine > Av. du Vivier d'Oie",
#     'descr_nl': 'Terhulpsesteenweg : Lorrainedreef > Diesdellelaan',
#     'detectors': ['SUL62_BDout1'],
#     'number_of_lanes': 1,
#     'orientation': 100,
#     'traverse_name': 'SUL62_BDout'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.3552931128139, 50.8357944967423],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16876',
#    'properties': {'descr_en': 'Tunnel Louise - entrée : Midi > Basilique',
#     'descr_fr': 'Tunnel Louise - entrée : Midi > Basilique',
#     'descr_nl': 'Louizatunnel - inrit : Zuid > Basiliek',
#     'detectors': ['LOU_TD2_1', 'LOU_TD2_2'],
#     'number_of_lanes': 2,
#     'orientation': 230,
#     'traverse_name': 'LOU_TD2'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.37525612793937, 50.8790703836989],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16820',
#    'properties': {'descr_en': 'Tunnel Van Praet > Centre',
#     'descr_fr': 'Tunnel Van Praet > Centre',
#     'descr_nl': 'Van Praettunnel > Centrum',
#     'detectors': ['VP_103_1', 'VP_103_2'],
#     'number_of_lanes': 2,
#     'orientation': 5,
#     'traverse_name': 'VP_103'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.35544182807463, 50.8353942207238],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16821',
#    'properties': {'descr_en': 'Tunnel Stéphanie - sortie : Centre + Basilique > Cambre',
#     'descr_fr': 'Tunnel Stéphanie - sortie : Centre + Basilique > Cambre',
#     'descr_nl': 'Stefaniatunnel - uitrit : Centrum + Basiliek > Kameren',
#     'detectors': ['STE_TD2_1', 'STE_TD2_2'],
#     'number_of_lanes': 2,
#     'orientation': 325,
#     'traverse_name': 'STE_TD2'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.40454037395511, 50.8314671373189],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16822',
#    'properties': {'descr_en': 'Tunnel Boileau > Meiser',
#     'descr_fr': 'Tunnel Boileau > Meiser',
#     'descr_nl': 'Boileautunnel > Meiser',
#     'detectors': ['BOI_203_1', 'BOI_203_2'],
#     'number_of_lanes': 2,
#     'orientation': 200,
#     'traverse_name': 'BOI_203'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.4061742687768, 50.8424655931645],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16837',
#    'properties': {'descr_en': 'Tunnel Georges Henri > La Cambre',
#     'descr_fr': 'Tunnel Georges Henri > La Cambre',
#     'descr_nl': 'Georges Henritunnel > Ter Kameren',
#     'detectors': ['GH_103_1', 'GH_103_2', 'GH_103_3'],
#     'number_of_lanes': 3,
#     'orientation': 340,
#     'traverse_name': 'GH_103'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.35553982742218, 50.8560957594291],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16823',
#    'properties': {'descr_en': 'Tunnel Rogier > Basilique',
#     'descr_fr': 'Tunnel Rogier > Basilique',
#     'descr_nl': 'Rogiertunnel > Basiliek',
#     'detectors': ['ROG_TD2_1', 'ROG_TD2_2'],
#     'number_of_lanes': 2,
#     'orientation': 115,
#     'traverse_name': 'ROG_TD2'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.30990478561637, 50.8691421209151],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16841',
#    'properties': {'descr_en': 'Av. Charles-Quint : Rue F. Beeckmans > Av. de Villegas',
#     'descr_fr': 'Av. Charles-Quint : Rue F. Beeckmans > Av. de Villegas',
#     'descr_nl': 'Keizer Karellaan : F. Beeckmansstraat > de Villegaslaan',
#     'detectors': ['SGN02_BBout1', 'SGN02_BBout2'],
#     'number_of_lanes': 2,
#     'orientation': 115,
#     'traverse_name': 'SGN02_BBout'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.40797458487389, 50.8373973283749],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16842',
#    'properties': {'descr_en': 'Tunnel Tervueren > Centre',
#     'descr_fr': 'Tunnel Tervueren > Centre',
#     'descr_nl': 'Tervurentunnel > Centrum',
#     'detectors': ['TER_TD1_1', 'TER_TD1_2'],
#     'number_of_lanes': 2,
#     'orientation': 110,
#     'traverse_name': 'TER_TD1'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.38602388862269, 50.8433192595553],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16824',
#    'properties': {'descr_en': 'Tunnel Belliard-Cortenbergh avant entrée Joyeuse Entrée > E40',
#     'descr_fr': 'Tunnel Belliard-Cortenbergh avant entrée Joyeuse Entrée > E40',
#     'descr_nl': 'Belliard-Cortenberghtunnel vóór inrit Blijde Inkomst > E40',
#     'detectors': ['BEL_TD4_1', 'BEL_TD4_2'],
#     'number_of_lanes': 2,
#     'orientation': 230,
#     'traverse_name': 'BEL_TD4'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.40240769836913, 50.8498633167017],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16825',
#    'properties': {'descr_en': 'Tunnel Reyers-Meiser > Meiser',
#     'descr_fr': 'Tunnel Reyers-Meiser > Meiser',
#     'descr_nl': 'Reyers-Meisertunnel > Meiser',
#     'detectors': ['RME_TD1_1'],
#     'number_of_lanes': 1,
#     'orientation': 120,
#     'traverse_name': 'RME_TD1'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.36676532148926, 50.8420224998488],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16861',
#    'properties': {'descr_en': 'Av. des Arts : Rue Montoyer > Rue Belliard',
#     'descr_fr': 'Av. des Arts : Rue Montoyer > Rue Belliard',
#     'descr_nl': 'Kunstlaan : Montoyerstraat > Belliardstraat',
#     'detectors': ['SB1201_BAout1',
#      'SB1201_BAout2',
#      'SB1201_BAout3',
#      'SB1201_BAout4'],
#     'number_of_lanes': 4,
#     'orientation': 195,
#     'traverse_name': 'SB1201_BAout'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.35533670092783, 50.8356012609392],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16826',
#    'properties': {'descr_en': 'Tunnel Stéphanie - sortie : Cambre > Centre',
#     'descr_fr': 'Tunnel Stéphanie - sortie : Cambre > Centre',
#     'descr_nl': 'Stefaniatunnel - uitrit : Kameren > Centrum',
#     'detectors': ['STE_TD1_1'],
#     'number_of_lanes': 1,
#     'orientation': 140,
#     'traverse_name': 'STE_TD1'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.36338369892443, 50.8932787104298],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16855',
#    'properties': {'descr_en': 'Av. des Croix du Feu : rue de Heembeek > rue de Wand',
#     'descr_fr': 'Av. des Croix du Feu : rue de Heembeek > rue de Wand',
#     'descr_nl': 'Vuurkruisenlaan : Heembeekstraat > De Wandstraat',
#     'detectors': ['SB0246_BAout3', 'SB0246_BAout4'],
#     'number_of_lanes': 2,
#     'orientation': 125,
#     'traverse_name': 'SB0246_BAout'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.36618462645944, 50.8411585614729],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16827',
#    'properties': {'descr_en': 'Tunnel Trône > Basilique',
#     'descr_fr': 'Tunnel Trône > Basilique',
#     'descr_nl': 'Troontunnel > Basilique',
#     'detectors': ['TRO_TD2_1', 'TRO_TD2_2'],
#     'number_of_lanes': 2,
#     'orientation': 200,
#     'traverse_name': 'TRO_TD2'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.40646945858465, 50.8422366718252],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16843',
#    'properties': {'descr_en': 'Tunnel Georges Henri > Meiser',
#     'descr_fr': 'Tunnel Georges Henri > Meiser',
#     'descr_nl': 'Georges Henritunnel > Meiser',
#     'detectors': ['GH_203_1', 'GH_203_2', 'GH_203_3'],
#     'number_of_lanes': 3,
#     'orientation': 160,
#     'traverse_name': 'GH_203'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.3105789088027, 50.8688324426319],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16856',
#    'properties': {'descr_en': 'Av. Charles-Quint : Rue F. Beeckmans > Rue de la Métairie',
#     'descr_fr': 'Av. Charles-Quint : Rue F. Beeckmans > Rue de la Métairie',
#     'descr_nl': 'Keizer Karellaan : F. Beeckmansstraat > Boerderijstraat',
#     'detectors': ['SGN02_BAout1', 'SGN02_BAout2'],
#     'number_of_lanes': 2,
#     'orientation': 295,
#     'traverse_name': 'SGN02_BAout'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.34876977877793, 50.8582030897834],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16863',
#    'properties': {'descr_en': "Quai de Willebroeck : Quai de la Voirie > Pl. de l'Yser",
#     'descr_fr': "Quai de Willebroeck : Quai de la Voirie > Pl. de l'Yser",
#     'descr_nl': 'Willebroekkaai : Ruimingskaai > IJzerplein',
#     'detectors': ['SB020_BCin1', 'SB020_BCin2', 'SB020_BCin3'],
#     'number_of_lanes': 3,
#     'orientation': 25,
#     'traverse_name': 'SB020_BCin'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.3623772388971, 50.8388649715647],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16828',
#    'properties': {'descr_en': 'Tunnel Porte de Namur > Midi',
#     'descr_fr': 'Tunnel Porte de Namur > Midi',
#     'descr_nl': 'Naamsepoorttunnel > Zuid',
#     'detectors': ['PNA_103_1', 'PNA_103_2'],
#     'number_of_lanes': 2,
#     'orientation': 55,
#     'traverse_name': 'PNA_103'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.38398848375424, 50.7985971582363],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16864',
#    'properties': {'descr_en': "Ch. de la Hulpe : Dr. de Lorraine > Av. S'Heeren Huys",
#     'descr_fr': "Ch. de la Hulpe : Dr. de Lorraine > Av. S'Heeren Huys",
#     'descr_nl': "Terhulpsesteenweg : Lorrainedreef > 's-Herenhuislaan",
#     'detectors': ['SUL62_BHout1', 'SUL62_BHout2'],
#     'number_of_lanes': 2,
#     'orientation': 280,
#     'traverse_name': 'SUL62_BHout'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.38247616107358, 50.7990014935703],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16862',
#    'properties': {'descr_en': 'Dr. de Lorraine : Ch. de la Hulpe > Av. de Boitsfort',
#     'descr_fr': 'Dr. de Lorraine : Ch. de la Hulpe > Av. de Boitsfort',
#     'descr_nl': 'Lorrainedreef : Terhulpsesteenweg > Bosvoordselaan',
#     'detectors': ['SUL62_BGout1'],
#     'number_of_lanes': 1,
#     'orientation': 210,
#     'traverse_name': 'SUL62_BGout'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.36916800191254, 50.8488531910046],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16829',
#    'properties': {'descr_en': 'Tunnel Madou > Basilique',
#     'descr_fr': 'Tunnel Madou > Basilique',
#     'descr_nl': 'Madoutunnel > Basiliek',
#     'detectors': ['MAD_203_1', 'MAD_203_2'],
#     'number_of_lanes': 2,
#     'orientation': 170,
#     'traverse_name': 'MAD_203'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.3674756097824, 50.8237391810756],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16830',
#    'properties': {'descr_en': 'Tunnel Vleurgat > La Cambre',
#     'descr_fr': 'Tunnel Vleurgat > La Cambre',
#     'descr_nl': 'Vleurgattunnel > Ter Kameren',
#     'detectors': ['VLE_103_1', 'VLE_103_2'],
#     'number_of_lanes': 2,
#     'orientation': 330,
#     'traverse_name': 'VLE_203'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.38650625946081, 50.8417380768795],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16831',
#    'properties': {'descr_en': 'Tunnel Belliard-Cinquantenaire > Tervueren',
#     'descr_fr': 'Tunnel Belliard-Cinquantenaire > Tervueren',
#     'descr_nl': 'Belliard-Jubelparktunnel > Tervueren',
#     'detectors': ['BET_TD3_1', 'BET_TD3_2'],
#     'number_of_lanes': 2,
#     'orientation': 290,
#     'traverse_name': 'BET_TD3'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.37533832168132, 50.8786382689061],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16832',
#    'properties': {'descr_en': 'Tunnel Van Praet > A12',
#     'descr_fr': 'Tunnel Van Praet > A12',
#     'descr_nl': 'Van Praettunnel > A12',
#     'detectors': ['VP_203_1', 'VP_203_2'],
#     'number_of_lanes': 2,
#     'orientation': 185,
#     'traverse_name': 'VP_203'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.38273308951594, 50.7978984925948],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16871',
#    'properties': {'descr_en': 'Dr. de Lorraine : Ch. de la Hulpe > Dr. du Caporal',
#     'descr_fr': 'Dr. de Lorraine : Ch. de la Hulpe > Dr. du Caporal',
#     'descr_nl': 'Lorrainedreef : Terhulpsesteenweg > Korporaaldreef',
#     'detectors': ['SUL62_BA1out1'],
#     'number_of_lanes': 1,
#     'orientation': 350,
#     'traverse_name': 'SUL62_BA1out'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.38400074128935, 50.7986361284092],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16877',
#    'properties': {'descr_en': "Ch. de la Hulpe : Av. S'Heeren Huys > Dr. de Lorraine",
#     'descr_fr': "Ch. de la Hulpe : Av. S'Heeren Huys > Dr. de Lorraine",
#     'descr_nl': "Terhulpsesteenweg : 's-Herenhuislaan > Lorrainedreef",
#     'detectors': ['SUL62_BDin1'],
#     'number_of_lanes': 1,
#     'orientation': 100,
#     'traverse_name': 'SUL62_BDin'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.3632826010712, 50.8926726489919],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16872',
#    'properties': {'descr_en': "Av. Van Praet : Av. de l'Araucaria > Ch. de Vilvorde",
#     'descr_fr': "Av. Van Praet : Av. de l'Araucaria > Ch. de Vilvorde",
#     'descr_nl': 'Van Praetlaan : Araucarialaan > Vilvoordsesteenweg',
#     'detectors': ['SB0246_BXout1', 'SB0246_BXout2'],
#     'number_of_lanes': 2,
#     'orientation': 295,
#     'traverse_name': 'SB0246_BXout'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.34919110900498, 50.8582377341188],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16873',
#    'properties': {'descr_en': "Quai de Willebroeck : Pl. de l'Yser > Bd S. Bolivar",
#     'descr_fr': "Quai de Willebroeck : Pl. de l'Yser > Bd S. Bolivar",
#     'descr_nl': 'Willebroekkaai : IJzerplein > Simon Bolivarlaan',
#     'detectors': ['SB020_BDout1', 'SB020_BDout2'],
#     'number_of_lanes': 2,
#     'orientation': 200,
#     'traverse_name': 'SB020_BDout'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.36312754900289, 50.8279565134595],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16833',
#    'properties': {'descr_en': 'Tunnel Bailli > La Cambre',
#     'descr_fr': 'Tunnel Bailli > La Cambre',
#     'descr_nl': 'Baillitunnel > Ter Kameren',
#     'detectors': ['BAI_TD2_1', 'BAI_TD2_2'],
#     'number_of_lanes': 2,
#     'orientation': 330,
#     'traverse_name': 'BAI_TD2'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.36302375091686, 50.8281804402839],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16834',
#    'properties': {'descr_en': 'Tunnel Bailli > Centre',
#     'descr_fr': 'Tunnel Bailli > Centre',
#     'descr_nl': 'Baillitunnel > Centrum',
#     'detectors': ['BAI_TD1_1', 'BAI_TD1_2'],
#     'number_of_lanes': 2,
#     'orientation': 150,
#     'traverse_name': 'BAI_TD1'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.38594029684627, 50.8412923720853],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16878',
#    'properties': {'descr_en': 'Tunnel Loi : entrée Joyeuse Entrée > Centre',
#     'descr_fr': 'Tunnel Loi : entrée Joyeuse Entrée > Centre',
#     'descr_nl': 'Wettunnel : inrit Blijde Inkomst > Centrum',
#     'detectors': ['LOI_109_6'],
#     'number_of_lanes': 1,
#     'orientation': 200,
#     'traverse_name': 'LOI_109'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.34917883601026, 50.8577737668987],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16879',
#    'properties': {'descr_en': "Bd. d'Anvers : Pl. de l'Yser > Bd. d'Anvers",
#     'descr_fr': "Bd. d'Anvers : Pl. de l'Yser > Bd. d'Anvers",
#     'descr_nl': 'Antwerpselaan : IJzerplein > Antwerpselaan',
#     'detectors': ['SB020_BAout1', 'SB020_BAout2'],
#     'number_of_lanes': 2,
#     'orientation': 290,
#     'traverse_name': 'SB020_BAout'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.40752081535691, 50.8371066241582],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16874',
#    'properties': {'descr_en': 'Tunnel Montgomery > Meiser',
#     'descr_fr': 'Tunnel Montgomery > Meiser',
#     'descr_nl': 'Montgomerytunnel > Meiser',
#     'detectors': ['MON_TD2_1', 'MON_TD2_2'],
#     'number_of_lanes': 2,
#     'orientation': 195,
#     'traverse_name': 'MON_TD2'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.35760384671979, 50.8931166449733],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16880',
#    'properties': {'descr_en': 'Av. du Parc Royal : Av. de Madrid > A12',
#     'descr_fr': 'Av. du Parc Royal : Av. de Madrid > A12',
#     'descr_nl': 'Koninklijk Parklaan : Madridlaan > A12',
#     'detectors': ['SB0236_BCout1', 'SB0236_BCout2'],
#     'number_of_lanes': 2,
#     'orientation': 140,
#     'traverse_name': 'SB0236_BCout'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.36627279945376, 50.8415215046334],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16881',
#    'properties': {'descr_en': 'Tunnel Trône > Midi',
#     'descr_fr': 'Tunnel Trône > Midi',
#     'descr_nl': 'Troontunnel > Zuid',
#     'detectors': ['TRO_TD1_1', 'TRO_TD1_2'],
#     'number_of_lanes': 2,
#     'orientation': 20,
#     'traverse_name': 'TRO_TD1'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.38459966479754, 50.8421984666756],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16882',
#    'properties': {'descr_en': 'Tunnel Belliard - bifurcation > Cinquantenaire',
#     'descr_fr': 'Tunnel Belliard - bifurcation > Cinquantenaire',
#     'descr_nl': 'Belliardtunnel - bifurcatie > Jubelpark',
#     'detectors': ['BET_TD2_1', 'BET_TD2_2'],
#     'number_of_lanes': 2,
#     'orientation': 290,
#     'traverse_name': 'BET_TD2_12'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.40717157399957, 50.8374887718277],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16883',
#    'properties': {'descr_en': 'Tunnel Tervueren > Tervueren',
#     'descr_fr': 'Tunnel Tervueren > Tervueren',
#     'descr_nl': 'Tervurentunnel > Tervuren',
#     'detectors': ['TER_TD2_1', 'TER_TD2_2'],
#     'number_of_lanes': 2,
#     'orientation': 290,
#     'traverse_name': 'TER_TD2'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [4.3949361577435, 50.8471522117605],
#     'geometry_name': 'geom',
#     'type': 'Point'},
#    'id': 'traverse.16884',
#    'properties': {'descr_en': 'Tunnel Belliard-Cortenbergh > E40',
#     'descr_fr': 'Tunnel Belliard-Cortenbergh > E40',
#     'descr_nl': 'Belliard-Cortenberghtunnel > E40',
#     'detectors': ['BEL_TD5_1', 'BEL_TD5_2'],
#     'number_of_lanes': 2,
#     'orientation': 240,
#     'traverse_name': 'BEL_TD5'},
#    'type': 'Feature'}],
#  'requestDate': '2019/10/23 14:29:07',
#  'totalFeatures': 66,
#  'type': 'FeatureCollection'}

# %% [markdown]
# We are interested by the `features` key where all the attributes of each traverse is stored.
# We are first going to create an empty DataFrame to allow us to store all this information.

# %%
import pandas as pd

traverse_devices_df = pd.DataFrame(columns = ["traverse_request_date", "traverse_id", "traverse_name", "traverse_descr_nl", 
                                              "traverse_descr_fr", "traverse_descr_en", "traverse_longitude", 
                                              "traverse_latitude", "traverse_orientation", "traverse_number_of_lanes", 
                                              "detector_1", "detector_2", "detector_3", "detector_4", "detector_5"])

# %% [markdown]
# We are extracting the content of the json object to fill our DataFrame.

# %%
traverse_request_date = json_traverse_devices_content["requestDate"]

i = 0

for item in json_traverse_devices_content['features']:
    traverse_id = item["id"]
    traverse_longitude = item["geometry"]["coordinates"][0]
    traverse_latitude = item["geometry"]["coordinates"][1]
    traverse_name = item["properties"]["traverse_name"]
    traverse_descr_nl = item["properties"]["descr_nl"]
    traverse_descr_fr = item["properties"]["descr_fr"]
    traverse_descr_en = item["properties"]["descr_en"]
    traverse_orientation = item["properties"]["orientation"]
    traverse_number_of_lanes = item["properties"]["number_of_lanes"]
    
    detector_dict = dict.fromkeys(["detector_1", "detector_2", "detector_3", "detector_4", "detector_5"])
    detector_list = ["detector_1", "detector_2", "detector_3", "detector_4", "detector_5"]
    det_count = 0
    for detector in item["properties"]["detectors"]:
        detector_dict[detector_list[det_count]] = detector
        det_count += 1
    traverse_devices_df.loc[i] = [traverse_request_date, traverse_id, traverse_name, traverse_descr_nl, traverse_descr_fr, 
                                  traverse_descr_en, traverse_longitude, traverse_latitude, traverse_orientation, 
                                  traverse_number_of_lanes, detector_dict["detector_1"], detector_dict["detector_2"], 
                                  detector_dict["detector_3"], detector_dict["detector_4"], detector_dict["detector_5"]]  
    i += 1

# %% [markdown]
# In order for the `traverse_longitude`and `traverse_latitude` columns to be considered as geographical data by Tableau, we need to convert them as string.

# %%
coordinates = ["traverse_longitude", "traverse_latitude"]

for coord in coordinates:
    traverse_devices_df[coord] = traverse_devices_df[coord].astype(str).str.replace(".", ",")

traverse_devices_df[["traverse_longitude", "traverse_latitude"]]
# Out:
#    traverse_longitude traverse_latitude
# 0    4,35695853200681  50,8365913344471
# 1    4,36852282769307  50,8457551811458
# 2    4,34920696698087  50,8579974792338
# 3    4,38682173223087  50,8418347237431
# 4    4,35756294930224  50,8930000247203
# 5    4,39448722891204  50,8402207235509
# 6    4,39448383899941  50,8401254712678
# 7    4,39855753338851   50,848036684476
# 8    4,38057760894757  50,7990396839219
# 9    4,38083487018981  50,8402353941657
# 10   4,36755767589685  50,8427194155479
# 11   4,36847711930287  50,8454212127438
# 12   4,34435175156863  50,8333292051346
# 13   4,36589069362988  50,8406560215622
# 14   4,37430823073347  50,8413096175241
# 15   4,36705817328361  50,8529271483494
# 16   4,34504691225078  50,8332713997418
# 17   4,40763894749183  50,8157452748348
# 18   4,40739340672444  50,8371268392137
# 19   4,35470097195641   50,835614034075
# 20   4,35551041573263  50,8357236560642
# 21   4,38279259633245  50,7979060948513
# 22   4,36897150728288  50,8491539713291
# 23   4,36796757498138  50,8233719130158
# 24   4,35529733515802  50,8560960838814
# 25   4,36169819780213  50,8384799439303
# 26   4,40760212115242  50,8156243058095
# 27   4,38058685119678  50,7990691599242
# 28    4,3552931128139  50,8357944967423
# 29   4,37525612793937  50,8790703836989
# ..                ...               ...
# 36   4,38602388862269  50,8433192595553
# 37   4,40240769836913  50,8498633167017
# 38   4,36676532148926  50,8420224998488
# 39   4,35533670092783  50,8356012609392
# 40   4,36338369892443  50,8932787104298
# 41   4,36618462645944  50,8411585614729
# 42   4,40646945858465  50,8422366718252
# 43    4,3105789088027  50,8688324426319
# 44   4,34876977877793  50,8582030897834
# 45    4,3623772388971  50,8388649715647
# 46   4,38398848375424  50,7985971582363
# 47   4,38247616107358  50,7990014935703
# 48   4,36916800191254  50,8488531910046
# 49    4,3674756097824  50,8237391810756
# 50   4,38650625946081  50,8417380768795
# 51   4,37533832168132  50,8786382689061
# 52   4,38273308951594  50,7978984925948
# 53   4,38400074128935  50,7986361284092
# 54    4,3632826010712  50,8926726489919
# 55   4,34919110900498  50,8582377341188
# 56   4,36312754900289  50,8279565134595
# 57   4,36302375091686  50,8281804402839
# 58   4,38594029684627  50,8412923720853
# 59   4,34917883601026  50,8577737668987
# 60   4,40752081535691  50,8371066241582
# 61   4,35760384671979  50,8931166449733
# 62   4,36627279945376  50,8415215046334
# 63   4,38459966479754  50,8421984666756
# 64   4,40717157399957  50,8374887718277
# 65    4,3949361577435  50,8471522117605
#
# [66 rows x 2 columns]

# %% [markdown]
# In order to save the data properly into a BigQuery table, we need to convert `traverse_orientation` and `traverse_number_of_lanes` to integer.

# %%
int_cols = ["traverse_orientation", "traverse_number_of_lanes"]

for col in int_cols:
    traverse_devices_df[col] = traverse_devices_df[col].astype(int)

# %% [markdown]
# We drop `traverse_descr_en` as it contains the same information as `traverse_descr_fr`. We also modify the value of `traverse_descr_fr` at row 9. Otherwise, it will cause an issue when we'll try to write the BigQuery table. So far, we still don't have found the cause.

# %%
traverse_devices_df.drop("traverse_descr_en", axis=1, inplace=True)
traverse_devices_df.loc[9,"traverse_descr_fr"] = traverse_devices_df.loc[9,"traverse_descr_nl"]

# %%
traverse_devices_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66 entries, 0 to 65
# Data columns (total 14 columns):
# traverse_request_date       66 non-null object
# traverse_id                 66 non-null object
# traverse_name               66 non-null object
# traverse_descr_nl           66 non-null object
# traverse_descr_fr           66 non-null object
# traverse_longitude          66 non-null object
# traverse_latitude           66 non-null object
# traverse_orientation        66 non-null int64
# traverse_number_of_lanes    66 non-null int64
# detector_1                  66 non-null object
# detector_2                  54 non-null object
# detector_3                  7 non-null object
# detector_4                  3 non-null object
# detector_5                  1 non-null object
# dtypes: int64(2), object(12)
# memory usage: 10.2+ KB

# %% [markdown]
# We define a function to check if a table already exists or not.

# %%
from google.cloud import bigquery
from google.cloud.exceptions import NotFound

def doesTableExist(project_id, dataset_id, table_id):
    bigquery_client = bigquery.Client(project_id)
    dataset_ref = bigquery_client.dataset(dataset_id)
    table_ref = dataset_ref.table(table_id)

    try:
        table = bigquery_client.get_table(table_ref)
        if table:
            print("Table {}\'s existence sucessfully proved!".format(table_ref))
            return True
    except NotFound as error:
        # ...do some processing ...
        print("Whoops! Table {} doesn\'t exist here! Ref: {}".format(table_ref, error))
        return False

# %% [markdown]
# We need to make sure we have `pandas_gbq` version 0.3.1 or higher.

# %%
# TO DO: If you have to update pandas_gbq version and that you run this code in Google Cloud Datalab, uncomment the below code and run it. 
#       Afterwards, restart your server and the version should be updated.

# !pip install --upgrade pandas_gbq==0.11.0

# %%
import pandas_gbq
print(pandas_gbq.__version__)
# Out:
# 0.11.0

# %% [markdown]
# We only overwrite the existing table if detectors are added.

# %%
# TO DO: uncomment the below line and define where to store your table.

# project_id = ""
# dataset_id = ""
# table_id = ""
dataset_table_id = dataset_id + "." + table_id

if not doesTableExist(project_id,dataset_id,table_id):
    try:
        pandas_gbq.to_gbq(traverse_devices_df, dataset_table_id, project_id=project_id, if_exists='fail')
    except:
        pass
else:
    old_traverse_devices_df = pandas_gbq.read_gbq("SELECT traverse_name from {}".format(dataset_table_id), project_id = project_id)
    if traverse_devices_df.shape[0] != old_traverse_devices_df.shape[0]:
        pandas_gbq.to_gbq(traverse_devices_df, dataset_table_id, project_id=project_id, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# <ipython-input-4-d33be739a648> in <module>
#       6 dataset_table_id = dataset_id + "." + table_id
#       7
# ----> 8 if not doesTableExist(project_id,dataset_id,table_id):
#       9     try:
#      10         pandas_gbq.to_gbq(traverse_devices_df, dataset_table_id, project_id=project_id, if_exists='fail')
#
# <ipython-input-3-45e306df3b35> in doesTableExist(project_id, dataset_id, table_id)
#       3
#       4 def doesTableExist(project_id, dataset_id, table_id):
# ----> 5     bigquery_client = bigquery.Client(project_id)
#       6     dataset_ref = bigquery_client.dataset(dataset_id)
#       7     table_ref = dataset_ref.table(table_id)
#
# ~\Anaconda3\lib\site-packages\google\cloud\bigquery\client.py in __init__(self, project, credentials, _http, location, default_query_job_config, client_info, client_options)
#     174     ):
#     175         super(Client, self).__init__(
# --> 176             project=project, credentials=credentials, _http=_http
#     177         )
#     178
#
# ~\Anaconda3\lib\site-packages\google\cloud\client.py in __init__(self, project, credentials, _http)
#     225     def __init__(self, project=None, credentials=None, _http=None):
#     226         _ClientProjectMixin.__init__(self, project=project)
# --> 227         Client.__init__(self, credentials=credentials, _http=_http)
#
# ~\Anaconda3\lib\site-packages\google\cloud\client.py in __init__(self, credentials, _http)
#     130             raise ValueError(_GOOGLE_AUTH_CREDENTIALS_HELP)
#     131         if credentials is None and _http is None:
# --> 132             credentials, _ = google.auth.default()
#     133         self._credentials = google.auth.credentials.with_scopes_if_required(
#     134             credentials, self.SCOPE
#
# ~\Anaconda3\lib\site-packages\google\auth\_default.py in default(scopes, request)
#     315             return credentials, effective_project_id
#     316
# --> 317     raise exceptions.DefaultCredentialsError(_HELP_MESSAGE)
#
# DefaultCredentialsError: Could not automatically determine credentials. Please set GOOGLE_APPLICATION_CREDENTIALS or explicitly create credentials and re-run the application. For more information, please see https://cloud.google.com/docs/authentication/getting-started

# %% [markdown]
# We create the list of traverse names as we'll need it to extract live data.

# %%
list_of_traverse_name = []
for item in json_traverse_devices_content["features"]:
    traverse_name = item["properties"]["traverse_name"]
    list_of_traverse_name.append(traverse_name)

list_of_traverse_name
# Out:
# ['LOU_TD1',
#  'ARL_103',
#  'SB020_BBin',
#  'LOI_103',
#  'SB0236_BHout',
#  'CIN_TD1',
#  'CIN_TD2',
#  'RCE_TD1',
#  'SUL62_BHin',
#  'BE_TD1',
#  'SB121_BBin',
#  'ARL_203',
#  'HAL_292',
#  'TRO_203',
#  'SB125_BBout',
#  'BOT_TD2',
#  'HAL_191',
#  'DEL_103_12',
#  'MON_TD1',
#  'LOU_110',
#  'STE_TD3',
#  'SUL62_BGin',
#  'MAD_103',
#  'VLE_103',
#  'ROG_TD1',
#  'PNA_203',
#  'DEL_103_6',
#  'SUL62_BDout',
#  'LOU_TD2',
#  'VP_103',
#  'STE_TD2',
#  'BOI_203',
#  'GH_103',
#  'ROG_TD2',
#  'SGN02_BBout',
#  'TER_TD1',
#  'BEL_TD4',
#  'RME_TD1',
#  'SB1201_BAout',
#  'STE_TD1',
#  'SB0246_BAout',
#  'TRO_TD2',
#  'GH_203',
#  'SGN02_BAout',
#  'SB020_BCin',
#  'PNA_103',
#  'SUL62_BHout',
#  'SUL62_BGout',
#  'MAD_203',
#  'VLE_203',
#  'BET_TD3',
#  'VP_203',
#  'SUL62_BA1out',
#  'SUL62_BDin',
#  'SB0246_BXout',
#  'SB020_BDout',
#  'BAI_TD2',
#  'BAI_TD1',
#  'LOI_109',
#  'SB020_BAout',
#  'MON_TD2',
#  'SB0236_BCout',
#  'TRO_TD1',
#  'BET_TD2_12',
#  'TER_TD2',
#  'BEL_TD5']

# %% [markdown]
# ## Live request

# %% [markdown]
# Here are the parameters of the live request:
#
# - featureID: Optional parameter for :w live requests. The value should be a traverse name or lane detector.
# - interval: Optional parameter for live requests. The parameters makes a filter for the measurement time space. Possible values are '1', '5', '15', '60' and 'all'. The value defines the time space in minutes. The default value 'all', gives you all data.
# - includeLanes: Optional parameter for live requests. If the parameter is set 'true', the response gives also the data by lane. The default value is 'false'.
# - singleValue: Optional parameter for live requests. If the parameter is set 'true', the response gives only the last timestamp value. The default value is 'false'.
#
# Below we extract the real-time data off all the traverse and create an json object to store it.
#
# We will only focus on the last minute (`interval`: 1) and we'll take the last timestamp (`singleValue`: true).

# %%
parameters = {'request': 'live', 'interval': '1', 'singleValue': 'true'}
traverse_live_response = requests.get("http://data-mobility.brussels/traffic/api/counts/", params=parameters)
traverse_live_status_code = traverse_live_response.status_code
traverse_live_content = traverse_live_response.content
decoded_traverse_live_content = traverse_live_content.decode('utf-8') # Decode using the utf-8 encoding
json_traverse_live_content = json.loads(decoded_traverse_live_content)
json_traverse_live_content
# Out:
# {'data': {'ARL_103': {'results': {'1m': {'count': 37,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 32.0,
#      'speed': 0.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'ARL_203': {'results': {'1m': {'count': 40,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 22.0,
#      'speed': 50.5,
#      'start_time': '2019/10/23 14:27'}}},
#   'BAI_TD1': {'results': {'1m': {'count': 25,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 16.0,
#      'speed': 51.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'BAI_TD2': {'results': {'1m': {'count': 19,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 12.5,
#      'speed': 49.5,
#      'start_time': '2019/10/23 14:27'}}},
#   'BEL_TD4': {'results': {'1m': {'count': 11,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 2.5,
#      'speed': 70.5,
#      'start_time': '2019/10/23 14:27'}}},
#   'BEL_TD5': {'results': {'1m': {'count': 29,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 15.0,
#      'speed': 57.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'BET_TD2_12': {'results': {'1m': {'count': 13,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 9.0,
#      'speed': 45.5,
#      'start_time': '2019/10/23 14:27'}}},
#   'BET_TD3': {'results': {'1m': {'count': 5,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 1.0,
#      'speed': 60.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'BE_TD1': {'results': {'1m': {'count': 56,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 24.0,
#      'speed': 60.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'BOI_203': {'results': {'1m': {'count': 17,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 10.5,
#      'speed': 39.5,
#      'start_time': '2019/10/23 14:27'}}},
#   'BOT_TD2': {'results': {'1m': {'count': 44,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 31.0,
#      'speed': 51.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'CIN_TD1': {'results': {'1m': {'count': 11,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 8.0,
#      'speed': 53.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'CIN_TD2': {'results': {'1m': {'count': 11,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 7.0,
#      'speed': 70.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'DEL_103_12': {'results': {'1m': {'count': 33,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 16.0,
#      'speed': 58.5,
#      'start_time': '2019/10/23 14:27'}}},
#   'DEL_103_6': {'results': {'1m': {'count': 0,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 0.0,
#      'speed': 0.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'GH_103': {'results': {'1m': {'count': 30,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 12.0,
#      'speed': 58.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'GH_203': {'results': {'1m': {'count': 30,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 11.3333,
#      'speed': 81.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'HAL_191': {'results': {'1m': {'count': 24,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 14.0,
#      'speed': 47.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'HAL_292': {'results': {'1m': {'count': 26,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 14.5,
#      'speed': 73.5,
#      'start_time': '2019/10/23 14:27'}}},
#   'LOI_103': {'results': {'1m': {'count': 18,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 7.5,
#      'speed': 55.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'LOI_109': {'results': {'1m': {'count': 6,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 9.0,
#      'speed': 42.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'LOU_110': {'results': {'1m': {'count': 15,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 20.0,
#      'speed': 45.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'LOU_TD1': {'results': {'1m': {'count': 41,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 28.5,
#      'speed': 47.5,
#      'start_time': '2019/10/23 14:27'}}},
#   'LOU_TD2': {'results': {'1m': {'count': 32,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 14.0,
#      'speed': 59.5,
#      'start_time': '2019/10/23 14:27'}}},
#   'MAD_103': {'results': {'1m': {'count': 35,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 15.5,
#      'speed': 39.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'MAD_203': {'results': {'1m': {'count': 43,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 32.0,
#      'speed': 41.5,
#      'start_time': '2019/10/23 14:27'}}},
#   'MON_TD1': {'results': {'1m': {'count': 16,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 10.5,
#      'speed': 61.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'MON_TD2': {'results': {'1m': {'count': 15,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 8.5,
#      'speed': 57.5,
#      'start_time': '2019/10/23 14:27'}}},
#   'PNA_103': {'results': {'1m': {'count': 47,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 34.0,
#      'speed': 52.5,
#      'start_time': '2019/10/23 14:27'}}},
#   'PNA_203': {'results': {'1m': {'count': 52,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 38.0,
#      'speed': 51.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'RCE_TD1': {'results': {'1m': {'count': 20,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 34.0,
#      'speed': 42.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'RME_TD1': {'results': {'1m': {'count': 9,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 11.0,
#      'speed': 46.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'ROG_TD1': {'results': {'1m': {'count': 38,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 19.5,
#      'speed': 53.5,
#      'start_time': '2019/10/23 14:27'}}},
#   'ROG_TD2': {'results': {'1m': {'count': 17,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 34.5,
#      'speed': 15.5,
#      'start_time': '2019/10/23 14:27'}}},
#   'SB020_BAout': {'results': {'1m': {'count': 12,
#      'end_time': '2019/10/23 14:25',
#      'occupancy': 21.0,
#      'speed': 16.5,
#      'start_time': '2019/10/23 14:24'}}},
#   'SB020_BBin': {'results': {'1m': {'count': 8,
#      'end_time': '2019/10/23 14:25',
#      'occupancy': 11.5,
#      'speed': 8.0,
#      'start_time': '2019/10/23 14:24'}}},
#   'SB020_BCin': {'results': {'1m': {'count': 13,
#      'end_time': '2019/10/23 14:25',
#      'occupancy': 6.66667,
#      'speed': 13.0,
#      'start_time': '2019/10/23 14:24'}}},
#   'SB020_BDout': {'results': {'1m': {'count': 14,
#      'end_time': '2019/10/23 14:25',
#      'occupancy': 8.5,
#      'speed': 31.5,
#      'start_time': '2019/10/23 14:24'}}},
#   'SB0236_BCout': {'results': {'1m': {'count': 21,
#      'end_time': '2019/10/23 14:25',
#      'occupancy': 8.5,
#      'speed': 46.0,
#      'start_time': '2019/10/23 14:24'}}},
#   'SB0236_BHout': {'results': {'1m': {'count': None,
#      'end_time': '-',
#      'occupancy': None,
#      'speed': None,
#      'start_time': '-'}}},
#   'SB0246_BAout': {'results': {'1m': {'count': None,
#      'end_time': '-',
#      'occupancy': None,
#      'speed': None,
#      'start_time': '-'}}},
#   'SB0246_BXout': {'results': {'1m': {'count': None,
#      'end_time': '-',
#      'occupancy': None,
#      'speed': None,
#      'start_time': '-'}}},
#   'SB1201_BAout': {'results': {'1m': {'count': 27,
#      'end_time': '2019/10/23 14:25',
#      'occupancy': 14.5,
#      'speed': 14.75,
#      'start_time': '2019/10/23 14:24'}}},
#   'SB121_BBin': {'results': {'1m': {'count': None,
#      'end_time': '-',
#      'occupancy': None,
#      'speed': None,
#      'start_time': '-'}}},
#   'SB125_BBin': {'results': {'1m': {'count': None,
#      'end_time': '-',
#      'occupancy': None,
#      'speed': None,
#      'start_time': '-'}}},
#   'SB125_BBout': {'results': {'1m': {'count': None,
#      'end_time': '-',
#      'occupancy': None,
#      'speed': None,
#      'start_time': '-'}}},
#   'SGN02_BAout': {'results': {'1m': {'count': None,
#      'end_time': '-',
#      'occupancy': None,
#      'speed': None,
#      'start_time': '-'}}},
#   'SGN02_BBout': {'results': {'1m': {'count': 17,
#      'end_time': '2019/10/23 14:25',
#      'occupancy': 7.5,
#      'speed': 31.5,
#      'start_time': '2019/10/23 14:24'}}},
#   'STE_TD1': {'results': {'1m': {'count': 8,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 9.0,
#      'speed': 38.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'STE_TD2': {'results': {'1m': {'count': 29,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 22.0,
#      'speed': 49.5,
#      'start_time': '2019/10/23 14:27'}}},
#   'STE_TD3': {'results': {'1m': {'count': 14,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 20.0,
#      'speed': 31.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'SUL62_BA1out': {'results': {'1m': {'count': None,
#      'end_time': '-',
#      'occupancy': None,
#      'speed': None,
#      'start_time': '-'}}},
#   'SUL62_BDin': {'results': {'1m': {'count': None,
#      'end_time': '-',
#      'occupancy': None,
#      'speed': None,
#      'start_time': '-'}}},
#   'SUL62_BDout': {'results': {'1m': {'count': None,
#      'end_time': '-',
#      'occupancy': None,
#      'speed': None,
#      'start_time': '-'}}},
#   'SUL62_BGin': {'results': {'1m': {'count': None,
#      'end_time': '-',
#      'occupancy': None,
#      'speed': None,
#      'start_time': '-'}}},
#   'SUL62_BGout': {'results': {'1m': {'count': 6,
#      'end_time': '2019/10/23 14:25',
#      'occupancy': 6.0,
#      'speed': 30.0,
#      'start_time': '2019/10/23 14:24'}}},
#   'SUL62_BHin': {'results': {'1m': {'count': None,
#      'end_time': '-',
#      'occupancy': None,
#      'speed': None,
#      'start_time': '-'}}},
#   'SUL62_BHout': {'results': {'1m': {'count': None,
#      'end_time': '-',
#      'occupancy': None,
#      'speed': None,
#      'start_time': '-'}}},
#   'TER_TD1': {'results': {'1m': {'count': 10,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 2.0,
#      'speed': 14.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'TER_TD2': {'results': {'1m': {'count': 13,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 12.0,
#      'speed': 20.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'TRO_203': {'results': {'1m': {'count': 15,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 16.5,
#      'speed': 18.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'TRO_TD1': {'results': {'1m': {'count': 36,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 17.5,
#      'speed': 61.5,
#      'start_time': '2019/10/23 14:27'}}},
#   'TRO_TD2': {'results': {'1m': {'count': 27,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 15.5,
#      'speed': 65.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'VLE_103': {'results': {'1m': {'count': 9,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 7.0,
#      'speed': 57.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'VLE_203': {'results': {'1m': {'count': 9,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 7.0,
#      'speed': 57.0,
#      'start_time': '2019/10/23 14:27'}}},
#   'VP_103': {'results': {'1m': {'count': 9,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 7.0,
#      'speed': 69.5,
#      'start_time': '2019/10/23 14:27'}}},
#   'VP_203': {'results': {'1m': {'count': 16,
#      'end_time': '2019/10/23 14:28',
#      'occupancy': 12.0,
#      'speed': 53.0,
#      'start_time': '2019/10/23 14:27'}}}},
#  'requestDate': '2019/10/23 14:29:15'}

# %% [markdown]
# We are interested by the `data` key where all the real-time data of each traverse is stored.
# We are first going to create an empty DataFrame to allow us to store all this information.

# %%
traverse_live_df = pd.DataFrame(columns = ['traverse_live_request_date', 'traverse_name', 'traverse_interval', 'traverse_count', 
                                           'traverse_speed', 'traverse_occupancy','traverse_start_time', 'traverse_end_time'])

# %% [markdown]
# We are extracting the content of the json object to fill our DataFrame.

# %%
traverse_live_request_date = json_traverse_live_content["requestDate"]
traverse_interval = '1m'
i = 0

for col in list_of_traverse_name:
    traverse_name = col
    traverse_count = json_traverse_live_content["data"][col]["results"][traverse_interval]["count"]
    traverse_speed = json_traverse_live_content["data"][col]["results"][traverse_interval]["speed"]
    traverse_occupancy = json_traverse_live_content["data"][col]["results"][traverse_interval]["occupancy"]
    traverse_start_time = json_traverse_live_content["data"][col]["results"][traverse_interval]["start_time"]
    traverse_end_time = json_traverse_live_content["data"][col]["results"][traverse_interval]["end_time"]
    
    traverse_live_df.loc[i] = [traverse_live_request_date, traverse_name, traverse_interval, traverse_count, traverse_speed, 
                               traverse_occupancy, traverse_start_time, traverse_end_time]
    i += 1

# %% [markdown]
# We start by dropping rows with null values as it won't be used in our visualizations.

# %%
traverse_live_df.dropna(inplace = True)

# %% [markdown]
# In order to save the data properly into a BigQuery table, we need to convert `traverse_count` to integer.

# %%
traverse_live_df["traverse_count"] = traverse_live_df["traverse_count"].astype(int)

# %% [markdown]
# In order for the `traverse_request_date`, `traverse_start_time` and `traverse_end_time` columns to be considered as dates by Tableau & BigQuery, we need apply some formatting.

# %%
traverse_live_df["traverse_live_request_date"] = pd.to_datetime(traverse_live_df["traverse_live_request_date"], format='%Y/%m/%d %H:%M')
traverse_live_df["traverse_start_time"] = pd.to_datetime(traverse_live_df["traverse_start_time"], format='%Y/%m/%d %H:%M', errors = 'coerce')
traverse_live_df["traverse_end_time"] = pd.to_datetime(traverse_live_df["traverse_end_time"], format='%Y/%m/%d %H:%M', errors = 'coerce')
traverse_live_df["traverse_end_date"] = traverse_live_df["traverse_end_time"].dt.date
traverse_live_df["traverse_end_date"] = pd.to_datetime(traverse_live_df["traverse_end_date"], format='%Y/%m/%d')
traverse_live_df["traverse_end_hour"] = traverse_live_df["traverse_end_time"].dt.time

# %%
traverse_live_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 0 to 65
# Data columns (total 10 columns):
# traverse_live_request_date    54 non-null datetime64[ns]
# traverse_name                 54 non-null object
# traverse_interval             54 non-null object
# traverse_count                54 non-null int64
# traverse_speed                54 non-null float64
# traverse_occupancy            54 non-null float64
# traverse_start_time           54 non-null datetime64[ns]
# traverse_end_time             54 non-null datetime64[ns]
# traverse_end_date             54 non-null datetime64[ns]
# traverse_end_hour             54 non-null object
# dtypes: datetime64[ns](4), float64(2), int64(1), object(3)
# memory usage: 4.6+ KB

# %% [markdown]
# We append new rows to the existing table.

# %%
# TO DO: uncomment the below line and define where to store your table.

# project_id = ""
# dataset_id = ""
# table_id = ""
dataset_table_id = dataset_id + "." + table_id

if not doesTableExist(project_id,dataset_id,table_id):
    try:
        pandas_gbq.to_gbq(traverse_live_df, dataset_table_id, project_id=project_id, if_exists='fail')
    except:
        pass
else:
    old_traverse_live_df = pandas_gbq.read_gbq("SELECT * from {}".format(dataset_table_id), project_id=project_id)

    for index, row in traverse_live_df.iterrows():
        traverse_live_last_update = row["traverse_end_time"]
        traverse_name = row["traverse_name"]
        old_traverse_live_last_update = old_traverse_live_df.loc[old_traverse_live_df["traverse_name"] == traverse_name, 
                                                                 "traverse_end_time"].max().tz_localize(None)
        if traverse_live_last_update <= old_traverse_live_last_update:
            traverse_live_df.drop(index, axis=0, inplace=True)

    pandas_gbq.to_gbq(traverse_live_df, dataset_table_id, project_id=project_id, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# <ipython-input-5-919456c5c10e> in <module>
#       6 dataset_table_id = dataset_id + "." + table_id
#       7
# ----> 8 if not doesTableExist(project_id,dataset_id,table_id):
#       9     try:
#      10         pandas_gbq.to_gbq(traverse_live_df, dataset_table_id, project_id=project_id, if_exists='fail')
#
# <ipython-input-3-45e306df3b35> in doesTableExist(project_id, dataset_id, table_id)
#       3
#       4 def doesTableExist(project_id, dataset_id, table_id):
# ----> 5     bigquery_client = bigquery.Client(project_id)
#       6     dataset_ref = bigquery_client.dataset(dataset_id)
#       7     table_ref = dataset_ref.table(table_id)
#
# ~\Anaconda3\lib\site-packages\google\cloud\bigquery\client.py in __init__(self, project, credentials, _http, location, default_query_job_config, client_info, client_options)
#     174     ):
#     175         super(Client, self).__init__(
# --> 176             project=project, credentials=credentials, _http=_http
#     177         )
#     178
#
# ~\Anaconda3\lib\site-packages\google\cloud\client.py in __init__(self, project, credentials, _http)
#     225     def __init__(self, project=None, credentials=None, _http=None):
#     226         _ClientProjectMixin.__init__(self, project=project)
# --> 227         Client.__init__(self, credentials=credentials, _http=_http)
#
# ~\Anaconda3\lib\site-packages\google\cloud\client.py in __init__(self, credentials, _http)
#     130             raise ValueError(_GOOGLE_AUTH_CREDENTIALS_HELP)
#     131         if credentials is None and _http is None:
# --> 132             credentials, _ = google.auth.default()
#     133         self._credentials = google.auth.credentials.with_scopes_if_required(
#     134             credentials, self.SCOPE
#
# ~\Anaconda3\lib\site-packages\google\auth\_default.py in default(scopes, request)
#     315             return credentials, effective_project_id
#     316
# --> 317     raise exceptions.DefaultCredentialsError(_HELP_MESSAGE)
#
# DefaultCredentialsError: Could not automatically determine credentials. Please set GOOGLE_APPLICATION_CREDENTIALS or explicitly create credentials and re-run the application. For more information, please see https://cloud.google.com/docs/authentication/getting-started
