# %% [markdown]
# # Introduction

# %% [markdown]
# The number of bikers are counted on several locations in the Brussels Region. The number of counters will be extended in the next years. To access the data, we can use the API or the geowebservices. Real time and historical data are available.
#
# In this project, we're going to get the latest livestream data for all bike counting poles each time the code is run. We're going to extract the livestream count with the number of bikers passed last hour, day and year. The counts are only updated when a bike passes the sensor.
#
# For more information on the API, please visit the [Brussels open datastore documentation](https://data-mobility.brussels/bike/api/counts/).
#
# As a reminder, our ultimate goal is to display traffic data as well as other mobility data such as this one on a dynamic map of Brussels.
# You can check the latest version of our map on [our Tableau Public link](https://public.tableau.com/profile/remy2092#!/vizhome/TrafficinBrussels/TrafficinBrussels) (a new link with hourly refreshed map will be published soon).

# %% [markdown]
# # Bike counts api

# %% [markdown]
# Here are the 4 types of HTTP GET requests we can perform with the API:
#
# - `devices`: List with name and location of the devices.
# - `live`: The livestream count with the number of bikers passed last hour, day and year. The counts are only updated when a bike passes the sensor. The timestamp of the last update can be found in the response. The timestamp indicates the local time.
# - `history`: Historical data by device. A count is given for every 15 minutes in UTC.
# - `time_gaps`: The timestamps used in the historical data.
#
# We're only going to focus on `devices` and `live` in this project.

# %% [markdown]
# ## Devices request (bike counting poles)

# %% [markdown]
# We extract the data and create an json object to store it.

# %%
# We use the 'pole_' prefix to describe the devices.

import requests
import json

pole_devices_response = requests.get("https://data-mobility.brussels/bike/api/counts/?request=devices")
pole_devices_status_code = pole_devices_response.status_code
pole_devices_content = pole_devices_response.content
decoded_pole_devices_content = pole_devices_content.decode('utf-8') # Decode using the utf-8 encoding
json_pole_devices_content = json.loads(decoded_pole_devices_content)
json_pole_devices_content
# Out:
# {'requestDate': '2019/10/17 11:14:08',
#  'type': 'FeatureCollection',
#  'totalFeatures': 13,
#  'features': [{'type': 'Feature',
#    'id': 'device.CB02411',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.37396099590842, 50.8818500025063],
#     'geometry_name': 'geom'},
#    'properties': {'device_name': 'CB02411',
#     'active': True,
#     'road_nl': 'Vilvoordsesteenweg - 1020 Brussel',
#     'road_fr': 'Chaussée de Vilvorde - 1020 Bruxelles',
#     'road_en': 'Chaussée de Vilvorde - 1020 Bruxelles',
#     'descr_nl': 'n/a',
#     'descr_fr': 'n/a',
#     'descr_en': 'n/a',
#     'lane_schema': 'https://data-mobility.brussels/media/bike/count/CB02411_laneSchema.png',
#     'basic_schema': 'https://data-mobility.brussels/media/bike/count/CB02411_basicSchema.png',
#     'detailed_schema': 'https://data-mobility.brussels/media/bike/count/CB02411_detailedSchema.png'}},
#   {'type': 'Feature',
#    'id': 'device.CB1142',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.37873799590318, 50.8435700025179],
#     'geometry_name': 'geom'},
#    'properties': {'device_name': 'CB1142',
#     'active': True,
#     'road_nl': 'Wetstraat 130 - 1000 Brussel',
#     'road_fr': 'Rue de la Loi 130 - 1000 Bruxelles',
#     'road_en': 'Rue de la Loi 130 - 1000 Bruxelles',
#     'descr_nl': 'De aantallen zijn gemeten op het fietspad van de Wetstraat richting centrum. Fietsbewegingen in beide richtingen zijn samengeteld. De aantallen worden telkens gereset aan het begin van een uur, een dag en een jaar.',
#     'descr_fr': 'Les nombres sont comptés sur la piste cyclable de la Rue de la Loi en direction du centre. Les mouvements des cyclistes dans les deux sens sont comptés ensemble. Les nombres sont chaque fois remis à zéro au début de l’heure, de la journée et de l’année.',
#     'descr_en': 'n/a',
#     'lane_schema': 'https://data-mobility.brussels/media/bike/count/CB1142_laneSchema.png',
#     'basic_schema': 'https://data-mobility.brussels/media/bike/count/CB1142_basicSchema.png',
#     'detailed_schema': 'https://data-mobility.brussels/media/bike/count/CB1142_detailedSchema.png'}},
#   {'type': 'Feature',
#    'id': 'device.CB1143',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.37881399590314, 50.843370002518],
#     'geometry_name': 'geom'},
#    'properties': {'device_name': 'CB1143',
#     'active': True,
#     'road_nl': 'Wetstraat 145 - 1000 Brussel',
#     'road_fr': 'Rue de la Loi 145 - 1000 Bruxelles',
#     'road_en': 'Rue de la Loi 145 - 1000 Bruxelles',
#     'descr_nl': 'n/a',
#     'descr_fr': 'n/a',
#     'descr_en': 'n/a',
#     'lane_schema': 'https://data-mobility.brussels/media/bike/count/CB1143_laneSchema.png',
#     'basic_schema': 'https://data-mobility.brussels/media/bike/count/CB1143_basicSchema.png',
#     'detailed_schema': 'https://data-mobility.brussels/media/bike/count/CB1143_detailedSchema.png'}},
#   {'type': 'Feature',
#    'id': 'device.CB1599',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.37925399589975, 50.812408002527],
#     'geometry_name': 'geom'},
#    'properties': {'device_name': 'CB1599',
#     'active': True,
#     'road_nl': 'Franklin Rooseveltlaan 48 - 1000 Brussel',
#     'road_fr': 'Avenue Franklin Rooseveltlaan 48 - 1000 Bruxelles',
#     'road_en': 'Avenue Franklin Rooseveltlaan 48 - 1000 Brussels',
#     'descr_nl': 'n/a',
#     'descr_fr': 'n/a',
#     'descr_en': 'n/a',
#     'lane_schema': 'https://data-mobility.brussels/media/bike/count/CB1599_laneSchema.png',
#     'basic_schema': 'https://data-mobility.brussels/media/bike/count/CB1599_basicSchema.png',
#     'detailed_schema': 'https://data-mobility.brussels/media/bike/count/CB1599_detailedSchema.png'}},
#   {'type': 'Feature',
#    'id': 'device.CB2105',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.34000999591242, 50.8404800025144],
#     'geometry_name': 'geom'},
#    'properties': {'device_name': 'CB2105',
#     'active': True,
#     'road_nl': 'Poincarélaan 75 - 1070 Anderlecht',
#     'road_fr': 'Boulevard Poincaré 75 - 1070 Anderlecht\t',
#     'road_en': 'Boulevard Poincaré 75 - 1070 Anderlecht\t',
#     'descr_nl': 'n/a',
#     'descr_fr': 'n/a',
#     'descr_en': 'n/a',
#     'lane_schema': 'https://data-mobility.brussels/media/bike/count/CB2105_laneSchema.png',
#     'basic_schema': 'https://data-mobility.brussels/media/bike/count/CB2105_basicSchema.png',
#     'detailed_schema': 'https://data-mobility.brussels/media/bike/count/CB2105_detailedSchema.png'}},
#   {'type': 'Feature',
#    'id': 'device.CEE016',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.38671899589886, 50.8213760025252],
#     'geometry_name': 'geom'},
#    'properties': {'device_name': 'CEE016',
#     'active': True,
#     'road_nl': 'Generaal Jacqueslaan 210 - 1050 Elsene',
#     'road_fr': 'Avenue Général Jacques 210 - 1050 Ixelles',
#     'road_en': 'Avenue Général Jacques 210 - 1050 Ixelles',
#     'descr_nl': 'n/a',
#     'descr_fr': 'n/a',
#     'descr_en': 'n/a',
#     'lane_schema': 'https://data-mobility.brussels/media/bike/count/CEE016_laneSchema.png',
#     'basic_schema': 'https://data-mobility.brussels/media/bike/count/CEE016_basicSchema.png',
#     'detailed_schema': 'https://data-mobility.brussels/media/bike/count/CEE016_detailedSchema.png'}},
#   {'type': 'Feature',
#    'id': 'device.CEK049',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.39389299589742, 50.8244800025252],
#     'geometry_name': 'geom'},
#    'properties': {'device_name': 'CEK049',
#     'active': True,
#     'road_nl': 'Generaal Jacqueslaan (VUB) - 1050 Elsene',
#     'road_fr': 'Boulevard Général Jacques (VUB) - 1050 Ixelles',
#     'road_en': 'Boulevard Général Jacques (VUB) - 1050 Ixelles',
#     'descr_nl': 'n/a',
#     'descr_fr': 'n/a',
#     'descr_en': 'n/a',
#     'lane_schema': 'https://data-mobility.brussels/media/bike/count/CEK049_laneSchema.png',
#     'basic_schema': 'https://data-mobility.brussels/media/bike/count/CEK049_basicSchema.png',
#     'detailed_schema': 'https://data-mobility.brussels/media/bike/count/CEK049_detailedSchema.png'}},
#   {'type': 'Feature',
#    'id': 'device.CEK18',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.40025899589741, 50.8392000025216],
#     'geometry_name': 'geom'},
#    'properties': {'device_name': 'CEK18',
#     'active': True,
#     'road_nl': 'Tervurenlaan 28 - 1040 Etterbeek',
#     'road_fr': 'Avenue de Tervueren 28 - 1040 Etterbeek',
#     'road_en': 'Avenue de Tervueren 28 - 1040 Etterbeek',
#     'descr_nl': 'n/a',
#     'descr_fr': 'n/a',
#     'descr_en': 'n/a',
#     'lane_schema': 'https://data-mobility.brussels/media/bike/count/CEK18_laneSchema.png',
#     'basic_schema': 'https://data-mobility.brussels/media/bike/count/CEK18_basicSchema.png',
#     'detailed_schema': 'https://data-mobility.brussels/media/bike/count/CEK18_detailedSchema.png'}},
#   {'type': 'Feature',
#    'id': 'device.CJM90',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.34123999591351, 50.8536300025108],
#     'geometry_name': 'geom'},
#    'properties': {'device_name': 'CJM90',
#     'active': True,
#     'road_nl': 'Koolmijnkaai 8 - 1080 Sint-Jans-Molenbeek',
#     'road_fr': 'Quai des charbonnages 8 - 1080 Molenbeek-Saint-Jean',
#     'road_en': 'Quai des charbonnages 8 - 1080 Molenbeek-Saint-Jean',
#     'descr_nl': 'n/a',
#     'descr_fr': 'n/a',
#     'descr_en': 'n/a',
#     'lane_schema': 'https://data-mobility.brussels/media/bike/count/CJM90_laneSchema.png',
#     'basic_schema': 'https://data-mobility.brussels/media/bike/count/CJM90_basicSchema.png',
#     'detailed_schema': 'https://data-mobility.brussels/media/bike/count/CJM90_detailedSchema.png'}},
#   {'type': 'Feature',
#    'id': 'device.CLW239',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.43482999588873, 50.8379980025259],
#     'geometry_name': 'geom'},
#    'properties': {'device_name': 'CLW239',
#     'active': True,
#     'road_nl': 'Woluwelaan 34 - 1200 Sint-Lambrechts-Woluwe',
#     'road_fr': 'Boulevard de la Woluwe 34 - 1200 Woluwe-Saint-Lambert',
#     'road_en': 'Boulevard Woluwe 34 - 1200 Woluwe-Saint-Lambert',
#     'descr_nl': 'n/a',
#     'descr_fr': 'n/a',
#     'descr_en': 'n/a',
#     'lane_schema': 'https://data-mobility.brussels/media/bike/count/CLW239_laneSchema.png',
#     'basic_schema': 'https://data-mobility.brussels/media/bike/count/CLW239_basicSchema.png',
#     'detailed_schema': 'https://data-mobility.brussels/media/bike/count/CLW239_detailedSchema.png'}},
#   {'type': 'Feature',
#    'id': 'device.COM205',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.43012099588802, 50.8202900025305],
#     'geometry_name': 'geom'},
#    'properties': {'device_name': 'COM205',
#     'active': True,
#     'road_nl': 'Vorstlaan 213 - 1170 Watermael-Boitsfort',
#     'road_fr': 'Boulevard du Souverain 213 - 1170 Watermaal-Bosvoorde',
#     'road_en': 'Boulevard du Souverain 213 - 1170 Watermaal-Bosvoorde',
#     'descr_nl': 'n/a',
#     'descr_fr': 'n/a',
#     'descr_en': 'n/a',
#     'lane_schema': 'https://data-mobility.brussels/media/bike/count/COM205_laneSchema.png',
#     'basic_schema': 'https://data-mobility.brussels/media/bike/count/COM205_basicSchema.png',
#     'detailed_schema': 'https://data-mobility.brussels/media/bike/count/COM205_detailedSchema.png'}},
#   {'type': 'Feature',
#    'id': 'device.CSG301',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.33618499591272, 50.8344700025158],
#     'geometry_name': 'geom'},
#    'properties': {'device_name': 'CSG301',
#     'active': True,
#     'road_nl': 'Fonsnylaan 48B - 1060 Sint-Gillis',
#     'road_fr': 'Avenue Fonsny 48B - 1060 Saint-Gilles',
#     'road_en': 'Avenue Fonsny 48B - 1060 Saint-Gilles',
#     'descr_nl': 'n/a',
#     'descr_fr': 'n/a',
#     'descr_en': 'n/a',
#     'lane_schema': 'https://data-mobility.brussels/media/bike/count/CSG301_laneSchema.png',
#     'basic_schema': 'https://data-mobility.brussels/media/bike/count/CSG301_basicSchema.png',
#     'detailed_schema': 'https://data-mobility.brussels/media/bike/count/CSG301_detailedSchema.png'}},
#   {'type': 'Feature',
#    'id': 'device.SJE181',
#    'geometry': {'type': 'Point',
#     'coordinates': [4.31571399592262, 50.8802970025002],
#     'geometry_name': 'geom'},
#    'properties': {'device_name': 'SJE181',
#     'active': True,
#     'road_nl': 'Tentoonstellingslaan - 1090 Jette',
#     'road_fr': "Avenue de l'Exposition - 1090 Jette",
#     'road_en': "Avenue de l'Exposition - 1090 Jette",
#     'descr_nl': 'n/a',
#     'descr_fr': 'n/a',
#     'descr_en': 'n/a',
#     'lane_schema': 'https://data-mobility.brussels/media/bike/count/SJE181_laneSchema.png',
#     'basic_schema': 'https://data-mobility.brussels/media/bike/count/SJE181_basicSchema.png',
#     'detailed_schema': 'https://data-mobility.brussels/media/bike/count/SJE181_detailedSchema.png'}}]}

# %% [markdown]
# We are interested by the `features` key where all the attributes of each traverse is stored.
# We are first going to create an empty DataFrame to allow us to store all this information.

# %%
import pandas as pd

pole_devices_df = pd.DataFrame(columns = ["pole_request_date", "pole_id", "pole_name", "pole_active", "pole_descr_nl", 
                                          "pole_descr_fr", "pole_descr_en", "pole_longitude", "pole_latitude", "pole_road_nl", 
                                          "pole_road_fr", "pole_road_en", "pole_lane_schema", "pole_basic_schema", 
                                          "pole_detailed_schema"])

# %% [markdown]
# We are extracting the content of the json object to fill our DataFrame.

# %%
pole_request_date = json_pole_devices_content["requestDate"]

i = 0

for item in json_pole_devices_content['features']:
    pole_id = item["id"]
    pole_longitude = item["geometry"]["coordinates"][0]
    pole_latitude = item["geometry"]["coordinates"][1]
    pole_name = item["properties"]["device_name"]
    pole_active = item["properties"]["active"]
    pole_descr_nl = item["properties"]["descr_nl"]
    pole_descr_fr = item["properties"]["descr_fr"]
    pole_descr_en = item["properties"]["descr_en"]
    pole_road_nl = item["properties"]["road_nl"]
    pole_road_fr = item["properties"]["road_fr"]
    pole_road_en = item["properties"]["road_en"]
    pole_lane_schema = item["properties"]["lane_schema"]
    pole_basic_schema = item["properties"]["basic_schema"]
    pole_detailed_schema = item["properties"]["detailed_schema"]
    
    pole_devices_df.loc[i] = [pole_request_date, pole_id, pole_name, pole_active, pole_descr_nl, pole_descr_fr, pole_descr_en, 
                              pole_longitude, pole_latitude, pole_road_nl, pole_road_fr, pole_road_en, pole_lane_schema, 
                              pole_basic_schema, pole_detailed_schema]  
    i += 1

# %%
pole_devices_df
# Out:
#       pole_request_date         pole_id pole_name pole_active  \
# 0   2019/10/17 11:14:08  device.CB02411   CB02411        True
# 1   2019/10/17 11:14:08   device.CB1142    CB1142        True
# 2   2019/10/17 11:14:08   device.CB1143    CB1143        True
# 3   2019/10/17 11:14:08   device.CB1599    CB1599        True
# 4   2019/10/17 11:14:08   device.CB2105    CB2105        True
# 5   2019/10/17 11:14:08   device.CEE016    CEE016        True
# 6   2019/10/17 11:14:08   device.CEK049    CEK049        True
# 7   2019/10/17 11:14:08    device.CEK18     CEK18        True
# 8   2019/10/17 11:14:08    device.CJM90     CJM90        True
# 9   2019/10/17 11:14:08   device.CLW239    CLW239        True
# 10  2019/10/17 11:14:08   device.COM205    COM205        True
# 11  2019/10/17 11:14:08   device.CSG301    CSG301        True
# 12  2019/10/17 11:14:08   device.SJE181    SJE181        True
#
#                                         pole_descr_nl  \
# 0                                                 n/a
# 1   De aantallen zijn gemeten op het fietspad van ...
# 2                                                 n/a
# 3                                                 n/a
# 4                                                 n/a
# 5                                                 n/a
# 6                                                 n/a
# 7                                                 n/a
# 8                                                 n/a
# 9                                                 n/a
# 10                                                n/a
# 11                                                n/a
# 12                                                n/a
#
#                                         pole_descr_fr pole_descr_en  \
# 0                                                 n/a           n/a
# 1   Les nombres sont comptés sur la piste cyclable...           n/a
# 2                                                 n/a           n/a
# 3                                                 n/a           n/a
# 4                                                 n/a           n/a
# 5                                                 n/a           n/a
# 6                                                 n/a           n/a
# 7                                                 n/a           n/a
# 8                                                 n/a           n/a
# 9                                                 n/a           n/a
# 10                                                n/a           n/a
# 11                                                n/a           n/a
# 12                                                n/a           n/a
#
#     pole_longitude  pole_latitude  \
# 0         4.373961      50.881850
# 1         4.378738      50.843570
# 2         4.378814      50.843370
# 3         4.379254      50.812408
# 4         4.340010      50.840480
# 5         4.386719      50.821376
# 6         4.393893      50.824480
# 7         4.400259      50.839200
# 8         4.341240      50.853630
# 9         4.434830      50.837998
# 10        4.430121      50.820290
# 11        4.336185      50.834470
# 12        4.315714      50.880297
#
#                                    pole_road_nl  \
# 0             Vilvoordsesteenweg - 1020 Brussel
# 1                  Wetstraat 130 - 1000 Brussel
# 2                  Wetstraat 145 - 1000 Brussel
# 3      Franklin Rooseveltlaan 48 - 1000 Brussel
# 4             Poincarélaan 75 - 1070 Anderlecht
# 5        Generaal Jacqueslaan 210 - 1050 Elsene
# 6      Generaal Jacqueslaan (VUB) - 1050 Elsene
# 7              Tervurenlaan 28 - 1040 Etterbeek
# 8     Koolmijnkaai 8 - 1080 Sint-Jans-Molenbeek
# 9   Woluwelaan 34 - 1200 Sint-Lambrechts-Woluwe
# 10     Vorstlaan 213 - 1170 Watermael-Boitsfort
# 11            Fonsnylaan 48B - 1060 Sint-Gillis
# 12            Tentoonstellingslaan - 1090 Jette
#
#                                          pole_road_fr  \
# 0               Chaussée de Vilvorde - 1020 Bruxelles
# 1                  Rue de la Loi 130 - 1000 Bruxelles
# 2                  Rue de la Loi 145 - 1000 Bruxelles
# 3   Avenue Franklin Rooseveltlaan 48 - 1000 Bruxelles
# 4           Boulevard Poincaré 75 - 1070 Anderlecht\t
# 5           Avenue Général Jacques 210 - 1050 Ixelles
# 6      Boulevard Général Jacques (VUB) - 1050 Ixelles
# 7             Avenue de Tervueren 28 - 1040 Etterbeek
# 8   Quai des charbonnages 8 - 1080 Molenbeek-Saint...
# 9   Boulevard de la Woluwe 34 - 1200 Woluwe-Saint-...
# 10  Boulevard du Souverain 213 - 1170 Watermaal-Bo...
# 11              Avenue Fonsny 48B - 1060 Saint-Gilles
# 12                Avenue de l'Exposition - 1090 Jette
#
#                                          pole_road_en  \
# 0               Chaussée de Vilvorde - 1020 Bruxelles
# 1                  Rue de la Loi 130 - 1000 Bruxelles
# 2                  Rue de la Loi 145 - 1000 Bruxelles
# 3    Avenue Franklin Rooseveltlaan 48 - 1000 Brussels
# 4           Boulevard Poincaré 75 - 1070 Anderlecht\t
# 5           Avenue Général Jacques 210 - 1050 Ixelles
# 6      Boulevard Général Jacques (VUB) - 1050 Ixelles
# 7             Avenue de Tervueren 28 - 1040 Etterbeek
# 8   Quai des charbonnages 8 - 1080 Molenbeek-Saint...
# 9     Boulevard Woluwe 34 - 1200 Woluwe-Saint-Lambert
# 10  Boulevard du Souverain 213 - 1170 Watermaal-Bo...
# 11              Avenue Fonsny 48B - 1060 Saint-Gilles
# 12                Avenue de l'Exposition - 1090 Jette
#
#                                      pole_lane_schema  \
# 0   https://data-mobility.brussels/media/bike/coun...
# 1   https://data-mobility.brussels/media/bike/coun...
# 2   https://data-mobility.brussels/media/bike/coun...
# 3   https://data-mobility.brussels/media/bike/coun...
# 4   https://data-mobility.brussels/media/bike/coun...
# 5   https://data-mobility.brussels/media/bike/coun...
# 6   https://data-mobility.brussels/media/bike/coun...
# 7   https://data-mobility.brussels/media/bike/coun...
# 8   https://data-mobility.brussels/media/bike/coun...
# 9   https://data-mobility.brussels/media/bike/coun...
# 10  https://data-mobility.brussels/media/bike/coun...
# 11  https://data-mobility.brussels/media/bike/coun...
# 12  https://data-mobility.brussels/media/bike/coun...
#
#                                     pole_basic_schema  \
# 0   https://data-mobility.brussels/media/bike/coun...
# 1   https://data-mobility.brussels/media/bike/coun...
# 2   https://data-mobility.brussels/media/bike/coun...
# 3   https://data-mobility.brussels/media/bike/coun...
# 4   https://data-mobility.brussels/media/bike/coun...
# 5   https://data-mobility.brussels/media/bike/coun...
# 6   https://data-mobility.brussels/media/bike/coun...
# 7   https://data-mobility.brussels/media/bike/coun...
# 8   https://data-mobility.brussels/media/bike/coun...
# 9   https://data-mobility.brussels/media/bike/coun...
# 10  https://data-mobility.brussels/media/bike/coun...
# 11  https://data-mobility.brussels/media/bike/coun...
# 12  https://data-mobility.brussels/media/bike/coun...
#
#                                  pole_detailed_schema
# 0   https://data-mobility.brussels/media/bike/coun...
# 1   https://data-mobility.brussels/media/bike/coun...
# 2   https://data-mobility.brussels/media/bike/coun...
# 3   https://data-mobility.brussels/media/bike/coun...
# 4   https://data-mobility.brussels/media/bike/coun...
# 5   https://data-mobility.brussels/media/bike/coun...
# 6   https://data-mobility.brussels/media/bike/coun...
# 7   https://data-mobility.brussels/media/bike/coun...
# 8   https://data-mobility.brussels/media/bike/coun...
# 9   https://data-mobility.brussels/media/bike/coun...
# 10  https://data-mobility.brussels/media/bike/coun...
# 11  https://data-mobility.brussels/media/bike/coun...
# 12  https://data-mobility.brussels/media/bike/coun...

# %% [markdown]
# In order for the `pole_longitude`and `pole_latitude` columns to be considered as geographical data by Tableau, we need to convert them as string.

# %%
pole_coordinates = ["pole_longitude", "pole_latitude"]

for coord in pole_coordinates:
    pole_devices_df[coord] = pole_devices_df[coord].astype(str).str.replace(".", ",")

pole_devices_df[["pole_longitude", "pole_latitude"]]
# Out:
#       pole_longitude     pole_latitude
# 0   4,37396099590842  50,8818500025063
# 1   4,37873799590318  50,8435700025179
# 2   4,37881399590314   50,843370002518
# 3   4,37925399589975   50,812408002527
# 4   4,34000999591242  50,8404800025144
# 5   4,38671899589886  50,8213760025252
# 6   4,39389299589742  50,8244800025252
# 7   4,40025899589741  50,8392000025216
# 8   4,34123999591351  50,8536300025108
# 9   4,43482999588873  50,8379980025259
# 10  4,43012099588802  50,8202900025305
# 11  4,33618499591272  50,8344700025158
# 12  4,31571399592262  50,8802970025002

# %%
pole_devices_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 0 to 12
# Data columns (total 15 columns):
# pole_request_date       13 non-null object
# pole_id                 13 non-null object
# pole_name               13 non-null object
# pole_active             13 non-null object
# pole_descr_nl           13 non-null object
# pole_descr_fr           13 non-null object
# pole_descr_en           13 non-null object
# pole_longitude          13 non-null object
# pole_latitude           13 non-null object
# pole_road_nl            13 non-null object
# pole_road_fr            13 non-null object
# pole_road_en            13 non-null object
# pole_lane_schema        13 non-null object
# pole_basic_schema       13 non-null object
# pole_detailed_schema    13 non-null object
# dtypes: object(15)
# memory usage: 1.6+ KB

# %% [markdown]
# We only overwrite the existing file if detectors are added.

# %%
import os

# TO DO: uncomment the below line and define your path on where to save your file.
# my_path = ""

if not os.path.isfile(my_path):
    pole_devices_df.to_csv(my_path, sep=";")
else:
    if not (len(pole_devices_df["pole_active"].unique()) == 1) and (pole_devices_df["pole_active"].unique()[0] == True):
        pole_devices_df.to_csv(my_path, sep=";", mode='a', header=False)

# %% [markdown]
# We create the list of bike counting poles as we'll need it to extract live data.

# %%
list_of_pole_name = []
for item in json_pole_devices_content["features"]:
    pole_name = item["properties"]["device_name"]
    list_of_pole_name.append(pole_name)

list_of_pole_name
# Out:
# ['CB02411',
#  'CB1142',
#  'CB1143',
#  'CB1599',
#  'CB2105',
#  'CEE016',
#  'CEK049',
#  'CEK18',
#  'CJM90',
#  'CLW239',
#  'COM205',
#  'CSG301',
#  'SJE181']

# %% [markdown]
# ## Live request (number of bikers by pole)

# %% [markdown]
# Below we extract the real-time data off all the bike counting poles and create an json object to store it.

# %%
parameters = {'request': 'live'}
bike_live_response = requests.get("http://data-mobility.brussels/bike/api/counts/", params=parameters)
bike_live_status_code = bike_live_response.status_code
bike_live_content = bike_live_response.content
decoded_bike_live_content = bike_live_content.decode('utf-8') # Decode using the utf-8 encoding
json_bike_live_content = json.loads(decoded_bike_live_content)
json_bike_live_content
# Out:
# {'requestDate': '2019/10/17 11:14:10',
#  'data': {'CB02411': {'hour_cnt': 3,
#    'day_cnt': 770,
#    'year_cnt': 370188,
#    'cnt_time': '2019/10/17 11:13:00'},
#   'CB1143': {'hour_cnt': 9,
#    'day_cnt': 253,
#    'year_cnt': 278299,
#    'cnt_time': '2019/10/17 11:13:00'},
#   'CB1599': {'hour_cnt': 5,
#    'day_cnt': 205,
#    'year_cnt': 112856,
#    'cnt_time': '2019/10/17 11:13:00'},
#   'CEK049': {'hour_cnt': 9,
#    'day_cnt': 367,
#    'year_cnt': 265085,
#    'cnt_time': '2019/10/17 11:13:00'},
#   'CEK18': {'hour_cnt': 1,
#    'day_cnt': 28,
#    'year_cnt': 95196,
#    'cnt_time': '2019/10/17 11:13:00'},
#   'CJM90': {'hour_cnt': 15,
#    'day_cnt': 565,
#    'year_cnt': 470849,
#    'cnt_time': '2019/10/17 11:13:00'},
#   'CLW239': {'hour_cnt': 5,
#    'day_cnt': 69,
#    'year_cnt': 71098,
#    'cnt_time': '2019/10/17 11:13:00'},
#   'COM205': {'hour_cnt': 0,
#    'day_cnt': 67,
#    'year_cnt': 59942,
#    'cnt_time': '2019/10/17 11:13:00'},
#   'CSG301': {'hour_cnt': 2,
#    'day_cnt': 130,
#    'year_cnt': 113321,
#    'cnt_time': '2019/10/17 11:13:00'},
#   'SJE181': {'hour_cnt': 0,
#    'day_cnt': 53,
#    'year_cnt': 22258,
#    'cnt_time': '2019/10/17 11:13:00'}}}

# %% [markdown]
# We are interested by the `data` key where all the real-time data of each traverse is stored.
# We are first going to create an empty DataFrame to allow us to store all this information.

# %%
bike_live_df = pd.DataFrame(columns = ['pole_live_request_date', 'pole_name', 'pole_hour_cnt', 'pole_day_cnt', 'pole_year_cnt', 
                                       'pole_cnt_time'])

# %%
pole_live_request_date = json_bike_live_content["requestDate"]
i = 0

for col in list_of_pole_name:
    pole_name = col
    try:
        pole_hour_cnt = json_bike_live_content["data"][col]["hour_cnt"]
        pole_day_cnt = json_bike_live_content["data"][col]["day_cnt"]
        pole_year_cnt = json_bike_live_content["data"][col]["year_cnt"]
        pole_cnt_time = json_bike_live_content["data"][col]["cnt_time"]
    except KeyError:
        continue

    bike_live_df.loc[i] = [pole_live_request_date, pole_name, pole_hour_cnt, pole_day_cnt, pole_year_cnt, pole_cnt_time]
    i += 1

# %%
bike_live_df
# Out:
#   pole_live_request_date pole_name pole_hour_cnt pole_day_cnt pole_year_cnt  \
# 0    2019/10/17 11:14:10   CB02411             3          770        370188
# 1    2019/10/17 11:14:10    CB1143             9          253        278299
# 2    2019/10/17 11:14:10    CB1599             5          205        112856
# 3    2019/10/17 11:14:10    CEK049             9          367        265085
# 4    2019/10/17 11:14:10     CEK18             1           28         95196
# 5    2019/10/17 11:14:10     CJM90            15          565        470849
# 6    2019/10/17 11:14:10    CLW239             5           69         71098
# 7    2019/10/17 11:14:10    COM205             0           67         59942
# 8    2019/10/17 11:14:10    CSG301             2          130        113321
# 9    2019/10/17 11:14:10    SJE181             0           53         22258
#
#          pole_cnt_time
# 0  2019/10/17 11:13:00
# 1  2019/10/17 11:13:00
# 2  2019/10/17 11:13:00
# 3  2019/10/17 11:13:00
# 4  2019/10/17 11:13:00
# 5  2019/10/17 11:13:00
# 6  2019/10/17 11:13:00
# 7  2019/10/17 11:13:00
# 8  2019/10/17 11:13:00
# 9  2019/10/17 11:13:00

# %% [markdown]
# In order for the `pole_live_request_date` and `pole_cnt_time` columns to be considered as dates by Tableau, we need apply some formatting.

# %%
bike_live_df["pole_live_request_date"] = pd.to_datetime(bike_live_df["pole_live_request_date"], format='%Y/%m/%d %H:%M')
bike_live_df["pole_cnt_time"] = pd.to_datetime(bike_live_df["pole_cnt_time"], format='%Y/%m/%d %H:%M', errors='coerce')
bike_live_df["pole_cnt_date"] = bike_live_df["pole_cnt_time"].dt.date
bike_live_df["pole_cnt_hour"] = bike_live_df["pole_cnt_time"].dt.time

# %%
bike_live_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 0 to 9
# Data columns (total 8 columns):
# pole_live_request_date    10 non-null datetime64[ns]
# pole_name                 10 non-null object
# pole_hour_cnt             10 non-null object
# pole_day_cnt              10 non-null object
# pole_year_cnt             10 non-null object
# pole_cnt_time             10 non-null datetime64[ns]
# pole_cnt_date             10 non-null object
# pole_cnt_hour             10 non-null object
# dtypes: datetime64[ns](2), object(6)
# memory usage: 720.0+ bytes

# %% [markdown]
# Finally we erase null values.

# %%
bike_live_df.dropna(inplace = True)

# %% [markdown]
# We append new rows to the existing .csv file.

# %%
# TO DO: uncomment the below line and define your path on where to save your file.
# my_path = ""

pole_live_last_update = bike_live_df["pole_cnt_time"].max()

if not os.path.isfile(my_path):
    bike_live_df.to_csv(my_path, sep=";")
else:
    old_pole_live_df = pd.read_csv(my_path, delimiter=";")
    pole_old_last_update = old_pole_live_df["pole_cnt_time"].max()
    if pole_live_last_update != pole_old_last_update:
        bike_live_df.to_csv(my_path, sep=";", mode='a', header=False)
